# %% [markdown]
# <a href="https://colab.research.google.com/github/james-hughes1/wdss-nlp-project/blob/main/NLP_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preamble

# %%
# Import libraries
# Data Processing
import pandas as pd
import numpy as np
import re
import datetime as dt
import random

# Statistical Modelling
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
from nltk.corpus import stopwords
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize

# Visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# Files
import os
import zipfile

# %%
# Download the GloVe embedding data
# This may take upto 3 minutes

# !wget --no-check-certificate \
     http://nlp.stanford.edu/data/glove.6B.zip \
     -O /tmp/glove.6B.zip
# Out:
# --2023-01-12 14:46:08--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2023-01-12 14:46:08--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2023-01-12 14:46:08--  https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘/tmp/glove.6B.zip’
#
# /tmp/glove.6B.zip   100%[===================>] 822.24M  4.88MB/s    in 2m 39s
#
# 2023-01-12 14:48:47 (5.18 MB/s) - ‘/tmp/glove.6B.zip’ saved [862182613/862182613]

# %%
# Read and format the twitter scrape .csv file
# Add the .csv file to the workspace or this won't work

tweets_df = pd.read_csv("Twitter Scrape 4.csv", usecols=["ID", "Date", "Likes", "Replies", "Retweets", "User ID", "Username", "Followers", "Verified", "Content"],
                        date_parser = pd.to_datetime, parse_dates=["Date"], encoding="UTF-8")
categories_df = pd.read_csv("Twitter Scrape 4_Categories_Lookup.csv", usecols=["Username", "Category"], encoding="UTF-8")
tweets_df["Time"] = [x.time() for x in tweets_df["Date"]]
tweets_df["Date"] = [x.date() for x in tweets_df["Date"]]
tweets_df = tweets_df[tweets_df["Username"].isin(list(categories_df["Username"]))]
tweets_df = tweets_df.merge(categories_df, on='Username', how='left')
tweets_df
# Out:
#                        ID        Date  Likes  Replies  Retweets  \
# 0     1063077542490505216  2018-11-15     42        3        32
# 1     1063102498725072896  2018-11-15     56        6        36
# 2     1063523438529314816  2018-11-16     11        0        12
# 3     1063718384670568448  2018-11-17    968       24       641
# 4     1063897312856920065  2018-11-17   1182       54       600
# ...                   ...         ...    ...      ...       ...
# 3546  1079340099631042560  2018-12-30      4        0         3
# 3547  1079437285584703488  2018-12-30     13        0         9
# 3548  1079437952931966976  2018-12-30   2234      197       373
# 3549  1079473478594486272  2018-12-30      9        0         8
# 3550  1079484894529634305  2018-12-30     21        1        12
#
#                   User ID         Username  Followers  Verified  \
# 0               214842351       PEspinosaC     123749         1
# 1                17463923           UNFCCC     962486         1
# 2               202313343       WRIClimate      72262         0
# 3                17463923           UNFCCC     962486         1
# 4      811229675758505984  antonioguterres    2029959         1
# ...                   ...              ...        ...       ...
# 3546            339754094  Connect4Climate     152693         1
# 3547  1019974187975430144      ExtinctionR     424553         1
# 3548             16220555     ElizabethMay     320612         1
# 3549            339754094  Connect4Climate     152693         1
# 3550             49760807        jellsmoor      62519         0
#
#                                                 Content      Time  \
# 0     Met with Costa Rican Environment Minister Carl...  14:33:31
# 1     The challenges of #climatechange, #desertifica...  16:12:41
# 2     BLOG: The upcoming climate change conference i...  20:05:21
# 3     Only 15 days until the @UN’s #ClimateChange co...  09:00:00
# 4     There is no alternative to the #ParisAgreement...  20:51:00
# ...                                                 ...       ...
# 3546  The needs for #ClimateAction are great, the op...  11:35:07
# 3547  .@moorlandernews - "The new agreements reached...  18:01:18
# 3548  Jason, You should have asked me. I was at COP2...  18:03:57
# 3549  [Blog] Water scarcity could cost some regions ...  20:25:07
# 3550  My thoughts on the biggest #climatechange stor...  21:10:29
#
#                         Category
# 0                     Politician
# 1     International Organisation
# 2     International Organisation
# 3     International Organisation
# 4                     Politician
# ...                          ...
# 3546                    Activist
# 3547                    Activist
# 3548                  Politician
# 3549                    Activist
# 3550                  Journalist
#
# [3551 rows x 12 columns]

# %%
# Dendogram plotting function

def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    plt.figure(figsize=(18,16))
    plt.title("Hierarchical Clustering Dendrogram")
    dendrogram(linkage_matrix, **kwargs)
    plt.xlabel("Number of points in node (or index of point if no parenthesis).")
    plt.show()

# %%
# Extract GloVe embedding data

with zipfile.ZipFile('/tmp/glove.6B.zip', 'r') as zip_ref:
    zip_ref.extractall('/tmp/glove')

embeddings_index = {}
f = open('/tmp/glove/glove.6B.100d.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %% [markdown]
# ## Text Pre-Processing

# %%
# Use regex to clean tweets

tweets_clean = []

for i in range(len(tweets_df)):
    tweet_raw = tweets_df["Content"][i]
    tweet_edit_1 = re.sub("http\S+", "", tweet_raw.lower())
    tweet_edit_2 = re.sub("&amp;", "and", tweet_edit_1)
    tweet_edit_3 = re.sub(r"[^@#%$£\w\⁠s,. ]", "", tweet_edit_2) # Filter emojis
    tweet_edit_4 = re.sub("[.,:;'\"] | [.,:;'\"]", " ", tweet_edit_3)
    tweets_clean.append(tweet_edit_4.strip())

# %%
# Sample cleaned tweets

tweets_clean[0]
# Out:
# 'met with costa rican environment minister carlos manuel rodríguez on the margins of #unbiodiversityconference #cop14 discussed importance of finalizing #parisagreement implementation guidelines at @unfccc #cop24 praised costa rica for its ambtious #carbonneutrality plans'

# %%
# Preprocessing hyperparameters

vocab_size = 20000
max_length = 24

# Tokenize text data

tokenizer = Tokenizer(oov_token="<OOV>",
                    num_words=vocab_size,
                    filters="")
tokenizer.fit_on_texts(tweets_clean)

# %%
# Construct word frequency dataframe

freq_analysis_df = pd.DataFrame(data = dict(tokenizer.word_counts).items(),
                                columns = ["Word", "Count"]).sort_values(by="Count",ascending=False)

# %%
# Build embedding_matrix

word_index = list(freq_analysis_df["Word"])
embedding_matrix = np.zeros((len(word_index), 100))
for i, word in enumerate(word_index):
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# ### Stop Words

# %%
nltk.download("stopwords")
stop_words = list(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
print("Fraction stop words: ", np.sum(freq_analysis_df[freq_analysis_df["Word"].isin(stop_words)]["Count"])/np.sum(freq_analysis_df["Count"]))
# Out:
# Fraction stop words:  0.36436058700209645

# %%
freq_analysis_df[freq_analysis_df["Count"]==1]
# Out:
#                    Word  Count
# 9557    @secretaryzinke      1
# 7523           greeting      1
# 9556           interior      1
# 9555        @sierraclub      1
# 8986        potentially      1
# ...                 ...    ...
# 5467        @tveinspire      1
# 5466           @gef_sgp      1
# 5464              artur      1
# 5462             zaheer      1
# 9780  #naturaldisasters      1
#
# [4974 rows x 2 columns]

# %% [markdown]
# ## Lexicon-Level Analysis

# %%
# Word Frequencies

freq_analysis_df.head(50)
# Out:
#                 Word  Count
# 10               the   5138
# 66                to   3545
# 23            #cop24   2869
# 34               and   2464
# 12                of   2058
# 21                at   1690
# 42                in   1573
# 47                 a   1491
# 56           climate   1301
# 26               for   1270
# 61                is   1152
# 9                 on   1118
# 171               we    974
# 36               are    813
# 101   #climateaction    689
# 681            cop24    570
# 132             that    558
# 231             from    550
# 198             more    548
# 135             this    543
# 57            change    515
# 247             have    494
# 162              our    489
# 161              you    482
# 32    #climatechange    476
# 1               with    459
# 49              will    441
# 214            world    418
# 334               by    414
# 51                be    379
# 128               it    349
# 361              how    342
# 647               as    335
# 165               us    329
# 495             live    326
# 244           global    322
# 238        emissions    310
# 358              can    304
# 367           action    304
# 157             need    303
# 208         #climate    297
# 18   #parisagreement    295
# 58        conference    286
# 99              must    279
# 262              out    277
# 384           people    271
# 590              not    271
# 27               its    269
# 267               an    260
# 325             just    257

# %% [markdown]
# ###Clustering

# %%
# Construct non-zero embedding matrix and assign cluster zero

freq_analysis_df["Cluster"] = -1
embeddings = []
valid_word_index = []
for i, row in enumerate(embedding_matrix):
    if (row==0).all():
        freq_analysis_df.iloc[i,2] = 0
    else:
        valid_word_index.append(i)
        embeddings.append(row)
embedding_matrix_nz = np.array(embeddings)

# %%
# Number of words not included in GloVe model

count1 = 0
count2 = 0
for row in freq_analysis_df[freq_analysis_df["Cluster"]==0]["Word"]:
  if "#" in row:
    count1+=1
  if "@" in row:
    count2+=1
print("Number of words unknown to GloVe: ", len(freq_analysis_df[freq_analysis_df["Cluster"]==0]))
print("Number of unique hashtags: ", count1)
print("Number of unique user @'s: ", count2)
# Out:
# Number of words unknown to GloVe:  3484
# Number of unique hashtags:  1105
# Number of unique user @'s:  1171

# %%
# K-Means Clustering

num_clusters_words = 50
# L2 normalising the embeddings makes K-means euclidean clustering the same as K-means cosine similarity clustering
kmeans_words = KMeans(n_clusters=num_clusters_words-1, random_state=0, n_init=10).fit(normalize(embedding_matrix_nz, axis=1))
for i in range(len(valid_word_index)):
    # We reserve zero for words that don't belong to the GloVe model.
    freq_analysis_df.iloc[valid_word_index[i],2] = kmeans_words.labels_[i]+1

# %%
# Agglomerative Clustering

num_clusters_words = 50
clustering_agg_words = AgglomerativeClustering(n_clusters=num_clusters_words-1, distance_threshold=None,
                                               affinity="cosine", linkage="average").fit(normalize(embedding_matrix_nz, axis=1))
for i in range(len(valid_word_index)):
    # We reserve zero for words that don't belong to the GloVe model
    freq_analysis_df.iloc[valid_word_index[i],2] = clustering_agg_words.labels_[i]+1

# %%
# Plot Dendrogram
# This cell only functions if n_clusters is not specified in the agglomerative clustering

plot_dendrogram(clustering_agg_words, truncate_mode="level", p=7)

# %%
# Display Cluster Information

for k in range(num_clusters_words):
  print("\nCluster: ",k)
  cluster_df = freq_analysis_df[freq_analysis_df["Cluster"]==k]
  print(len(cluster_df)/len(freq_analysis_df))
  print("Average Word Count: ", np.mean(cluster_df["Count"]))
  print(freq_analysis_df[freq_analysis_df["Cluster"]==k].iloc[:30])
# Out:
# Cluster:  0
# 0.3562007974644719
# Average Word Count:  4.315154994259472
#                       Word  Count  Cluster
# 23                  #cop24   2869        0
# 101         #climateaction    689        0
# 681                  cop24    570        0
# 32          #climatechange    476        0
# 208               #climate    297        0
# 18         #parisagreement    295        0
# 217                 @cop24    139        0
# 119                    @un    130        0
# 22                 @unfccc    127        0
# 2960             #mdbtalks    123        0
# 257      #talanoa4ambition    117        0
# 1943           #wwfclimate    112        0
# 353          #takeyourseat     89        0
# 139              #katowice     88        0
# 387            #stepup2018     83        0
# 1792            @worldbank     78        0
# 1425      @antonioguterres     73        0
# 70                    1.5c     70        0
# 1895    #adaptationmatters     67        0
# 894         @gretathunberg     67        0
# 2239             #pandahub     62        0
# 1575     #youthunstoppable     62        0
# 1007               #energy     60        0
# 1618                  ndcs     54        0
# 1008              #cdnpoli     53        0
# 1034  #extinctionrebellion     52        0
# 695               @ipcc_ch     51        0
# 848                   gtgt     49        0
# 656                talanoa     46        0
# 1615                   e3g     45        0
#
# Cluster:  1
# 0.014006747776300992
# Average Word Count:  2.9927007299270074
#                Word  Count  Cluster
# 1412          youre     33        1
# 68           theyre     24        1
# 1806           weve     23        1
# 1927         todays     23        1
# 2844           whos     16        1
# 3000           mdbs     14        1
# 5404          fijis     10        1
# 1981       countrys      9        1
# 1029        europes      9        1
# 5265           isnt      9        1
# 2905     livestream      9        1
# 1739  preindustrial      7        1
# 4814        deniers      6        1
# 5142       nonparty      6        1
# 4513     australias      6        1
# 6290    consumptive      6        1
# 3746      pavillion      5        1
# 7151            lts      5        1
# 4620         doesnt      5        1
# 4502       sealevel      5        1
# 1979    subnational      5        1
# 3335       nonstate      4        1
# 782         webinar      4        1
# 3276     coalmining      4        1
# 900         cochair      4        1
# 6432    stocktaking      4        1
# 7187        indepth      4        1
# 7092         admins      4        1
# 7950       roadmaps      4        1
# 1106          govts      4        1
#
# Cluster:  2
# 0.010632859625805133
# Average Word Count:  6.644230769230769
#              Word  Count  Cluster
# 2865     pavilion    143        2
# 1779       cities     47        2
# 685      building     45        2
# 717          land     40        2
# 2051         area     29        2
# 1221         city     26        2
# 2602      complex     25        2
# 568   communities     25        2
# 1156        built     18        2
# 4448        space     16        2
# 1023        areas     14        2
# 1937       centre     13        2
# 940      historic     13        2
# 2053        urban     12        2
# 1208    buildings     11        2
# 3318       center     11        2
# 2360    exclusive     10        2
# 1186     register      9        2
# 1192         farm      9        2
# 2309      outside      8        2
# 2230        homes      7        2
# 393        places      6        2
# 2871       occupy      6        2
# 799      preserve      6        2
# 4500      village      6        2
# 1261     landmark      6        2
# 3291     includes      5        2
# 2584    dedicated      4        2
# 2990   classrooms      4        2
# 3028         hall      4        2
#
# Cluster:  3
# 0.01605152847357121
# Average Word Count:  4.942675159235669
#               Word  Count  Cluster
# 1148     suffering     62        3
# 1003        crisis     54        3
# 369         threat     36        3
# 3632         risks     27        3
# 776           risk     24        3
# 270         tackle     22        3
# 394         facing     19        3
# 1013        damage     16        3
# 1826       effects     16        3
# 1900        shocks     15        3
# 559        poverty     15        3
# 1149  consequences     15        3
# 836        problem     14        3
# 605       disaster     13        3
# 1038      affected     11        3
# 1115         worst     11        3
# 2953     dangerous     10        3
# 2943      collapse     10        3
# 2800  catastrophic      9        3
# 2444     disasters      9        3
# 2204        caused      9        3
# 2203        deaths      9        3
# 447        failure      9        3
# 2952       prevent      9        3
# 2415        combat      8        3
# 3389     threatens      8        3
# 1142       unleash      8        3
# 8315       runaway      7        3
# 1481        stress      7        3
# 2071        burden      6        3
#
# Cluster:  4
# 0.01134853286984971
# Average Word Count:  11.585585585585585
#                Word  Count  Cluster
# 71           report    174        4
# 73             read    135        4
# 2740  announcements    107        4
# 204            call     84        4
# 203           press     71        4
# 743         message     53        4
# 652            news     40        4
# 96          address     39        4
# 366           calls     31        4
# 1350   announcement     30        4
# 676       statement     24        4
# 2571         speech     23        4
# 1500       speaking     20        4
# 627          speaks     20        4
# 815         calling     19        4
# 2622          media     19        4
# 4455          spoke     18        4
# 1781   conversation     18        4
# 532           heard     17        4
# 3249      interview     14        4
# 461         warning     14        4
# 3218           told     14        4
# 307           speak     13        4
# 416         details     13        4
# 1561      questions     11        4
# 820       delivered     10        4
# 2764         issued     10        4
# 3502          asked     10        4
# 350        comments      9        4
# 3346          words      9        4
#
# Cluster:  5
# 0.015438094264390145
# Average Word Count:  9.682119205298013
#               Word  Count  Cluster
# 438        leaders    182        5
# 103      president     95        5
# 680     presidency     60        5
# 671     government     57        5
# 953      political     57        5
# 726       national     45        5
# 5         minister     43        5
# 195     leadership     38        5
# 3030           u.s     36        5
# 841          panel     33        5
# 2147         state     33        5
# 624      coalition     32        5
# 455          chief     30        5
# 1809         civil     28        5
# 6436     ministers     27        5
# 794        parties     25        5
# 348           seat     23        5
# 2599      official     23        5
# 1944     secretary     20        5
# 1307   politicians     18        5
# 648           head     18        5
# 1783      alliance     17        5
# 1945       general     16        5
# 859     commission     16        5
# 1452        leader     16        5
# 150     delegation     15        5
# 4469        joined     13        5
# 2292       joining     13        5
# 1101       justice     12        5
# 4107  commissioner     11        5
#
# Cluster:  6
# 0.01605152847357121
# Average Word Count:  5.10828025477707
#                 Word  Count  Cluster
# 5662              al     70        6
# 391          against     68        6
# 189        activists     41        6
# 234          targets     40        6
# 1203        activist     34        6
# 259          actions     33        6
# 1394        movement     31        6
# 549       committing     25        6
# 248        committed     23        6
# 2232        fighting     20        6
# 454           rights     17        6
# 1762         protest     15        6
# 1415         radical     15        6
# 706   responsibility     14        6
# 3625      supporting     12        6
# 3089      destroying     12        6
# 2685       demanding     12        6
# 6481      protesters     11        6
# 4709     campaigners     11        6
# 4192         killing     10        6
# 4255       rebellion     10        6
# 1808          allies      9        6
# 1925     responsible      8        6
# 3493          police      8        6
# 9264        stealing      7        6
# 1228         capture      6        6
# 2679         marched      6        6
# 6614          saudis      6        6
# 7062      protestors      6        6
# 4708     journalists      5        6
#
# Cluster:  7
# 0.008690317963398425
# Average Word Count:  7.894117647058824
#          Word  Count  Cluster
# 1175        4     56        7
# 376        10     51        7
# 2165        5     46        7
# 1094        6     45        7
# 592         3     38        7
# 1050       12     34        7
# 825         2     29        7
# 824         1     26        7
# 2134       11     22        7
# 76         15     21        7
# 4267       35     21        7
# 2188        c     15        7
# 2372       30     15        7
# 708        14     15        7
# 2993     five     14        7
# 596         8     14        7
# 3806      100     13        7
# 4186        7     13        7
# 3256       13     13        7
# 1764       20     12        7
# 1890  degrees     11        7
# 1195       24     10        7
# 1765       22      8        7
# 770         9      8        7
# 1816       50      7        7
# 2999       25      7        7
# 1851      six      6        7
# 373        40      5        7
# 3801       19      4        7
# 3524    total      4        7
#
# Cluster:  8
# 0.024435129332379103
# Average Word Count:  123.40167364016736
#        Word  Count  Cluster
# 10      the   5138        8
# 34      and   2464        8
# 12       of   2058        8
# 42       in   1573        8
# 47        a   1491        8
# 26      for   1270        8
# 61       is   1152        8
# 36      are    813        8
# 132    that    558        8
# 198    more    548        8
# 135    this    543        8
# 247    have    494        8
# 1      with    459        8
# 49     will    441        8
# 334      by    414        8
# 51       be    379        8
# 128      it    349        8
# 647      as    335        8
# 165      us    329        8
# 358     can    304        8
# 262     out    277        8
# 384  people    271        8
# 590     not    271        8
# 27      its    269        8
# 267      an    260        8
# 629   about    253        8
# 199   today    247        8
# 88      now    227        8
# 120    here    227        8
# 124     all    220        8
#
# Cluster:  9
# 0.012473162253348328
# Average Word Count:  7.483606557377049
#              Word  Count  Cluster
# 281       updates    136        9
# 2469        daily    121        9
# 1161         lets     79        9
# 412      releases     59        9
# 54           blog     40        9
# 2457      webcast     37        9
# 2363     facebook     32        9
# 2157   highlights     25        9
# 2997            e     24        9
# 724        update     21        9
# 352        photos     15        9
# 2172         info     12        9
# 1845        globe     11        9
# 8037         text      9        9
# 3824         page      9        9
# 1737           1c      8        9
# 526       article      8        9
# 4278       online      7        9
# 6592        photo      7        9
# 7766      podcast      6        9
# 1214     download      6        9
# 3917         menu      6        9
# 702           app      6        9
# 9235    concludes      6        9
# 2486     streamed      6        9
# 4063   advisories      6        9
# 4064  distributed      6        9
# 4066      webpage      6        9
# 4137  contributor      6        9
# 1559        guide      6        9
#
# Cluster:  10
# 0.006747776300991719
# Average Word Count:  10.848484848484848
#           Word  Count  Cluster
# 2359       cet    143       10
# 1081       dec    112       10
# 574       2018     95       10
# 907         pm     70       10
# 1429      2030     36       10
# 4554      1900     28       10
# 421       0900     28       10
# 1242      2019     26       10
# 2015      2015     16       10
# 3519      1130     15       10
# 3560      2017     14       10
# 2358      12pm      6       10
# 3013      2025      6       10
# 4535      10am      6       10
# 1434      2040      5       10
# 4122      1830      5       10
# 3401      1700      5       10
# 2095      sept      5       10
# 7256       9am      4       10
# 3012      2021      4       10
# 4741       3pm      4       10
# 3200      1500      3       10
# 7495      1200      3       10
# 7967      1213      3       10
# 5431      1300      3       10
# 6763      1030      3       10
# 6840      1345      3       10
# 4555      1800      3       10
# 4402  mornings      3       10
# 3889      1315      3       10
#
# Cluster:  11
# 0.016460484613025253
# Average Word Count:  8.229813664596273
#              Word  Count  Cluster
# 495          live    326       11
# 1898   adaptation    113       11
# 1390      fashion     56       11
# 216         video     48       11
# 1337        story     46       11
# 948       reality     31       11
# 4588       newest     30       11
# 7321       sports     29       11
# 258       stories     29       11
# 67           show     27       11
# 2347           uk     27       11
# 222          best     24       11
# 531         voice     24       11
# 536         shows     23       11
# 3748         teen     21       11
# 3169     greatest     20       11
# 2544     inspired     19       11
# 1935          cop     17       11
# 3563       voices     15       11
# 351        videos     13       11
# 3002         tune     10       11
# 1490      amazing     10       11
# 1123        music     10       11
# 576         award      9       11
# 580   inspiration      9       11
# 4754         film      9       11
# 1063     showcase      9       11
# 1295          era      9       11
# 7688      segment      8       11
# 3081         book      8       11
#
# Cluster:  12
# 0.010939576730395665
# Average Word Count:  16.49532710280374
#              Word  Count  Cluster
# 238     emissions    310       12
# 1606       fossil    141       12
# 299        energy    137       12
# 673          coal    123       12
# 378        carbon     98       12
# 2644         fuel     93       12
# 335          2050     79       12
# 1222        water     57       12
# 426           gas     53       12
# 1607        fuels     43       12
# 425    greenhouse     40       12
# 996           oil     34       12
# 177           co2     30       12
# 341     renewable     29       12
# 617         solar     26       12
# 727          2020     26       12
# 1976    pollution     25       12
# 330   electricity     24       12
# 3635   renewables     21       12
# 1794      cleaner     20       12
# 3812    polluters     18       12
# 249      emission     18       12
# 1004    pipelines     17       12
# 705         waste     17       12
# 750   temperature     17       12
# 420         gases     16       12
# 1031        plant     16       12
# 2914         feed     15       12
# 707           ghg     14       12
# 1709         heat     11       12
#
# Cluster:  13
# 0.014517942950618546
# Average Word Count:  8.605633802816902
#               Word  Count  Cluster
# 1361   development    105       13
# 1002     solutions    100       13
# 571          power     64       13
# 166            use     61       13
# 185           data     39       13
# 1769      electric     33       13
# 272     developing     31       13
# 4      environment     31       13
# 941          build     30       13
# 540     technology     26       13
# 844        systems     25       13
# 331     generation     25       13
# 1258        create     21       13
# 1061    innovative     18       13
# 468       capacity     18       13
# 2004        system     18       13
# 1194       provide     17       13
# 3098      creating     16       13
# 4447    production     16       13
# 2388     developed     15       13
# 1247   information     15       13
# 3769      enhanced     15       13
# 1785        signal     14       13
# 733   technologies     13       13
# 1427        vision     13       13
# 3155      platform     13       13
# 1158       project     12       13
# 2228        supply     12       13
# 2568     available     12       13
# 842          using     12       13
#
# Cluster:  14
# 0.018914221449749514
# Average Word Count:  36.167567567567566
#           Word  Count  Cluster
# 21          at   1690       14
# 9           on   1118       14
# 231       from    550       14
# 310         up    250       14
# 838       time    185       14
# 81       years    148       14
# 241       over    101       14
# 424       year     97       14
# 304        was     97       14
# 959        day     93       14
# 196      ahead     89       14
# 830       last     72       14
# 97        next     71       14
# 90         set     70       14
# 151       week     69       14
# 278      after     59       14
# 396      first     56       14
# 699        off     51       14
# 69      taking     49       14
# 60    december     49       14
# 1743      past     44       14
# 570     before     44       14
# 1460      when     44       14
# 392     coming     44       14
# 614      start     41       14
# 1732   opening     40       14
# 957   released     39       14
# 856     during     37       14
# 1290      back     36       14
# 1854      down     35       14
#
# Cluster:  15
# 0.012370923218484818
# Average Word Count:  8.322314049586776
#             Word  Count  Cluster
# 59      katowice    234       15
# 1612          hi    157       15
# 355           rt     76       15
# 3251          et     70       15
# 5660  christiana     69       15
# 354           gt     43       15
# 2028       trump     33       15
# 1266          im     31       15
# 4604         thu     25       15
# 3202           f     21       15
# 3863           w     18       15
# 3027         ndc     15       15
# 1571         eus      9       15
# 4318     paribas      9       15
# 4317         bnp      9       15
# 4944         ppl      8       15
# 924          bam      7       15
# 3051         uns      7       15
# 3606         min      7       15
# 4325      brasil      6       15
# 3903          sg      6       15
# 4333          hr      6       15
# 1187        govt      5       15
# 6416          vp      4       15
# 6617         pow      4       15
# 2676          cc      4       15
# 3420       align      4       15
# 6964        ping      3       15
# 7061       admin      3       15
# 4798           @      3       15
#
# Cluster:  16
# 0.011144054800122687
# Average Word Count:  9.275229357798166
#               Word  Count  Cluster
# 58      conference    286       16
# 865         summit     92       16
# 969         events     54       16
# 122        meeting     50       16
# 2513       plenary     25       16
# 1511       welcome     23       16
# 407      delegates     23       16
# 661       speakers     21       16
# 2994         visit     17       16
# 2146       session     17       16
# 1705      gathered     16       16
# 1733      ceremony     16       16
# 3188  participants     15       16
# 968      attending     13       16
# 3510        gather     13       16
# 6974   ministerial     13       16
# 288           host     12       16
# 772    participate     12       16
# 153       meetings     11       16
# 2170         opens     11       16
# 4034  presentation     10       16
# 413         annual     10       16
# 2633     presented     10       16
# 2145        attend     10       16
# 1236       hosting     10       16
# 5826        hosted      9       16
# 1952    addressing      9       16
# 1948     sidelines      9       16
# 796     convention      9       16
# 658            eve      8       16
#
# Cluster:  17
# 0.014620181985482057
# Average Word Count:  7.454545454545454
#              Word  Count  Cluster
# 1347      billion     67       17
# 967       finance     60       17
# 246     companies     54       17
# 1391     industry     49       17
# 235      business     42       17
# 1316       sector     39       17
# 349         share     39       17
# 236    investment     35       17
# 1850  investments     32       17
# 368       biggest     24       17
# 2996        banks     22       17
# 1030      largest     22       17
# 597    businesses     20       17
# 3819      private     19       17
# 2257   management     18       17
# 3491      farmers     18       17
# 1282         bank     17       17
# 4717    financial     17       17
# 1467         jobs     17       17
# 2578    investors     17       17
# 2060    resources     16       17
# 1356     projects     16       17
# 2833        money     15       17
# 1844      markets     14       17
# 1357    investing     13       17
# 4212       market     12       17
# 1349         fund     11       17
# 4514      capital     11       17
# 2746          pay     11       17
# 1852      sectors     10       17
#
# Cluster:  18
# 0.00695225437071874
# Average Word Count:  10.161764705882353
#              Word  Count  Cluster
# 53         poland    223       18
# 945         paris    103       18
# 670        polish     94       18
# 858      european     27       18
# 826        canada     22       18
# 1046       europe     20       18
# 3371      swedish     19       18
# 5768       russia     18       18
# 1338      germany     11       18
# 2499       france     11       18
# 928      canadian     10       18
# 2522     brussels      8       18
# 1720     republic      7       18
# 3781     scotland      6       18
# 1717      austria      6       18
# 4953        japan      5       18
# 7038    canadians      5       18
# 3613  netherlands      5       18
# 926        quebec      4       18
# 854        norway      4       18
# 2403        dutch      4       18
# 7625         oslo      4       18
# 3555  switzerland      3       18
# 5319   luxembourg      3       18
# 4563      britain      3       18
# 3890        spain      3       18
# 3937      silesia      3       18
# 2820       nordic      3       18
# 1293     slovakia      3       18
# 1480    argentina      3       18
#
# Cluster:  19
# 0.01390450874143748
# Average Word Count:  4.213235294117647
#                Word  Count  Cluster
# 662        ambition    164       19
# 1899     resilience     43       19
# 256       inspiring     25       19
# 502         urgency     20       19
# 1928          truth     15       19
# 3187         spirit     14       19
# 3270     solidarity     13       19
# 7470  determination     10       19
# 2497       humanity     10       19
# 4660     incredible     10       19
# 2047          moral     10       19
# 4074     collective      9       19
# 4297       reminder      9       19
# 3351       thoughts      8       19
# 4941     imperative      8       19
# 3644          sense      6       19
# 1820    existential      6       19
# 6517     motivation      5       19
# 1400        inspire      5       19
# 5574      wellbeing      5       19
# 306        pleasure      4       19
# 2495    unequivocal      4       19
# 2662     inequality      4       19
# 5959          shame      4       19
# 2014       optimism      4       19
# 4812          faith      4       19
# 7723          grasp      4       19
# 4710         denial      4       19
# 3726        eternal      3       19
# 7384           sake      3       19
#
# Cluster:  20
# 0.011757489009303752
# Average Word Count:  5.165217391304348
#                  Word  Count  Cluster
# 872              dont     66       20
# 722             thank     56       20
# 1938          reminds     37       20
# 1478               am     37       20
# 1000             cant     36       20
# 683              hear     32       20
# 154            listen     26       20
# 4602              hey     25       20
# 1150           please     21       20
# 1267            proud     11       20
# 1114           remind     11       20
# 1907             wont     10       20
# 1396            tuned      9       20
# 1967              wow      8       20
# 1812             loud      7       20
# 1074  congratulations      7       20
# 3286              beg      7       20
# 984         grandkids      7       20
# 143           excited      6       20
# 1422         disagree      6       20
# 7320          awesome      6       20
# 1567            didnt      6       20
# 6161             hell      5       20
# 4270              die      5       20
# 3255             cops      5       20
# 2581             dear      4       20
# 3257             asks      4       20
# 3050         wherever      4       20
# 3034             glad      4       20
# 5185           hungry      4       20
#
# Cluster:  21
# 0.01492689909007259
# Average Word Count:  14.212328767123287
#                Word  Count  Cluster
# 56          climate   1301       21
# 432         weather     76       21
# 370          planet     73       21
# 863         warming     52       21
# 395         impacts     46       21
# 714     agriculture     31       21
# 486           earth     23       21
# 110           ocean     22       21
# 800         natural     21       21
# 433             sea     20       21
# 2890     mitigation     18       21
# 1314   temperatures     15       21
# 2428           soil     14       21
# 1157           wind     14       21
# 3909        forests     14       21
# 710    agricultural     13       21
# 4131      footprint     12       21
# 3168        manmade     11       21
# 3152     extinction     11       21
# 3153        horizon      8       21
# 4771      livestock      7       21
# 5047        melting      7       21
# 1983         forest      7       21
# 4591        cyclone      7       21
# 2916          crops      7       21
# 4870        feeding      6       21
# 3911  deforestation      6       21
# 3391   biodiversity      6       21
# 3490    livelihoods      6       21
# 4281         arctic      6       21
#
# Cluster:  22
# 0.01145077190471322
# Average Word Count:  9.660714285714286
#            Word  Count  Cluster
# 213      around     84       22
# 84         into     79       22
# 274     through     58       22
# 3019      point     56       22
# 1617     beyond     53       22
# 428       reach     51       22
# 181         via     50       22
# 1087    between     39       22
# 1377       main     35       22
# 593      across     33       22
# 1097    towards     27       22
# 1608     ground     26       22
# 2964     stream     23       22
# 3052    running     23       22
# 1528       side     23       22
# 458        open     19       22
# 747     central     18       22
# 2029     moving     18       22
# 1127      track     16       22
# 1741  continues     16       22
# 4423       fast     15       22
# 1738      above     15       22
# 808       drive     12       22
# 4155       line     12       22
# 406        away     12       22
# 1486       path     12       22
# 1441     within     11       22
# 3381       link      9       22
# 2103       deep      8       22
# 2218     begins      8       22
#
# Cluster:  23
# 0.016869440752479297
# Average Word Count:  19.490909090909092
#                Word  Count  Cluster
# 57           change    515       23
# 244          global    322       23
# 367          action    304       23
# 1790        support    161       23
# 401           major    151       23
# 289          future    140       23
# 313       important    104       23
# 595          strong     95       23
# 518             key     82       23
# 431         extreme     70       23
# 410         crucial     70       23
# 263          latest     47       23
# 781        response     47       23
# 792            role     44       23
# 210        critical     34       23
# 434           level     34       23
# 323        possible     34       23
# 1010       economic     33       23
# 1793  opportunities     27       23
# 142          thanks     27       23
# 1913          scale     26       23
# 2468        outcome     25       23
# 1042       strategy     24       23
# 2826         impact     24       23
# 100         success     23       23
# 1131        greater     22       23
# 1032        growing     21       23
# 1780        raising     21       23
# 1145      potential     20       23
# 1380           huge     19       23
#
# Cluster:  24
# 0.01748287496166036
# Average Word Count:  4.941520467836257
#                 Word  Count  Cluster
# 1064            ways     65       24
# 2636      scientific     47       24
# 746          matters     39       24
# 804       strategies     30       24
# 457           issues     25       24
# 1579      discussion     25       24
# 1436           human     22       24
# 1248      difference     21       24
# 801      generations     21       24
# 561          affects     20       24
# 16        importance     20       24
# 4259        changing     18       24
# 3518        findings     16       24
# 379        different     14       24
# 3269        approach     14       24
# 3764       knowledge     14       24
# 3349          nature     11       24
# 322   transformation     11       24
# 2385          common     11       24
# 812        essential     11       24
# 877             view     10       24
# 2717          gender     10       24
# 3630   understanding      9       24
# 2882           ideas      9       24
# 3437        outcomes      8       24
# 5429         lessons      8       24
# 3704     perspective      8       24
# 3590          depend      8       24
# 4038     experiences      7       24
# 4772       discusses      7       24
#
# Cluster:  25
# 0.011757489009303752
# Average Word Count:  8.68695652173913
#                Word  Count  Cluster
# 1071          youth     77       25
# 1014         health     76       25
# 496         science     55       25
# 3015        workers     49       25
# 207   international     48       25
# 1598      programme     43       25
# 1810        society     42       25
# 3225       children     34       25
# 513   environmental     32       25
# 562           women     28       25
# 3747        program     28       25
# 2524         public     25       25
# 1016     scientists     22       25
# 2922       students     20       25
# 2988         school     20       25
# 4621  organizations     20       25
# 4139      awareness     19       25
# 1603      education     18       25
# 1206           care     16       25
# 276      activities     16       25
# 1463        experts     16       25
# 2724      community     15       25
# 1811         groups     14       25
# 2621         social     14       25
# 2924          class     11       25
# 1836         degree     10       25
# 2696  contributions     10       25
# 1168       research     10       25
# 3566  organisations      9       25
# 2807           ngos      9       25
#
# Cluster:  26
# 0.0103261425212146
# Average Word Count:  4.405940594059406
#                 Word  Count  Cluster
# 1062             hub     42       26
# 158              air     35       26
# 1766       transport     30       26
# 1912          launch     26       26
# 3713        vehicles     23       26
# 1896       launching     14       26
# 179          driving     14       26
# 1152            ramp     13       26
# 2371           train     12       26
# 2751         powered     10       26
# 2380            mine     10       26
# 544   transportation     10       26
# 3894         vehicle      8       26
# 1722            bike      7       26
# 3775        shipping      7       26
# 3774        maritime      7       26
# 2370        arriving      7       26
# 3773         flights      7       26
# 3207      operations      6       26
# 3634            cars      6       26
# 2669         station      6       26
# 1080          travel      5       26
# 6716          landed      5       26
# 5262             fly      5       26
# 7861         landing      5       26
# 2108            duty      5       26
# 6928           crash      4       26
# 4199          driver      4       26
# 4844           canoe      4       26
# 5850           craft      4       26
#
# Cluster:  27
# 0.007974644719353849
# Average Word Count:  2.3076923076923075
#                 Word  Count  Cluster
# 3336           greta     26       27
# 4567          claire     11       27
# 5164   grandchildren      6       27
# 1622            sara      6       27
# 8235           hanna      5       27
# 1642             amy      5       27
# 7648          joanna      5       27
# 2631           elena      4       27
# 1645           megan      4       27
# 4284          mother      3       27
# 3851       astronaut      3       27
# 3955          andrea      3       27
# 8159  granddaughters      3       27
# 2949        patricia      3       27
# 1636       catherine      3       27
# 9023          pamela      3       27
# 1620         barbara      3       27
# 5364           laura      2       27
# 5416       elizabeth      2       27
# 5393        jennifer      2       27
# 4725            elsa      2       27
# 1667       madeleine      2       27
# 1663         vanessa      2       27
# 1679           irene      2       27
# 1659            lisa      2       27
# 1634         marlowe      2       27
# 1647           emily      2       27
# 1653            jess      2       27
# 1697          laurie      2       27
# 7017       katherine      2       27
#
# Cluster:  28
# 0.009814947346897045
# Average Word Count:  8.822916666666666
#             Word  Count  Cluster
# 65     countries    229       28
# 2877      fijian     54       28
# 445      peoples     35       28
# 3109  indigenous     28       28
# 186      pacific     28       28
# 1055      africa     25       28
# 1537       china     24       28
# 1078       india     23       28
# 2933       saudi     23       28
# 1056     regions     20       28
# 4228      arabia     18       28
# 1587   australia     16       28
# 225      islands     15       28
# 1234      brazil     14       28
# 1986       south     14       28
# 2700     african     14       28
# 5260   indonesia     13       28
# 145     maldives     11       28
# 6567      kuwait     11       28
# 1332      region     11       28
# 3294      island     11       28
# 2855     poorest     10       28
# 25          rica     10       28
# 3032        fiji     10       28
# 5304        asia      9       28
# 4364  population      9       28
# 1077      mexico      8       28
# 5300   continent      7       28
# 1929  bangladesh      7       28
# 3752      uganda      7       28
#
# Cluster:  29
# 0.012166445148757796
# Average Word Count:  1.9915966386554622
#               Word  Count  Cluster
# 365   attenborough     50       29
# 8496       nasheed      9       29
# 3108       ibrahim      4       29
# 4489      wolfgang      4       29
# 9687       cellist      4       29
# 5529        morano      4       29
# 5403         saran      3       29
# 6963           sze      3       29
# 6508       zhenhua      3       29
# 4515         adani      3       29
# 9633        seidel      3       29
# 9632        stefan      3       29
# 3035       andrzej      3       29
# 2913        millet      3       29
# 2907        amadou      3       29
# 9024         batty      3       29
# 7956       fetisov      2       29
# 1151       trudeau      2       29
# 7955         slava      2       29
# 5402           deo      2       29
# 4854          nils      2       29
# 4816         noone      2       29
# 4855         agger      2       29
# 8263      strasser      2       29
# 8130         singh      2       29
# 6507           xie      2       29
# 1681         aline      2       29
# 6975       presser      2       29
# 7074         cyril      2       29
# 1613       alister      2       29
#
# Cluster:  30
# 0.019732133728657602
# Average Word Count:  32.90673575129534
#              Word  Count  Cluster
# 66             to   3545       30
# 99           must    279       30
# 822          join    230       30
# 89    governments    208       30
# 1381         take    112       30
# 604          help     78       30
# 805       respond     76       30
# 30          plans     71       30
# 408          meet     66       30
# 909          give     62       30
# 268        urgent     59       30
# 172        should     59       30
# 439          step     58       30
# 440         fight     52       30
# 383       protect     52       30
# 921       discuss     51       30
# 324         needs     51       30
# 280        follow     50       30
# 521       achieve     45       30
# 482        needed     45       30
# 725         raise     41       30
# 831      continue     39       30
# 126       forward     33       30
# 2209         stop     33       30
# 2241     stepping     31       30
# 1385      deliver     31       30
# 621          move     30       30
# 1472      efforts     29       30
# 520       helping     26       30
# 106         bring     25       30
#
# Cluster:  31
# 0.0037828442899499027
# Average Word Count:  1.9189189189189189
#              Word  Count  Cluster
# 793          24th      9       31
# 1734          4th      8       31
# 2174      century      5       31
# 4090          1st      4       31
# 3379          2nd      4       31
# 5809         14th      4       31
# 5465   celebrated      3       31
# 2619          3rd      3       31
# 5385           st      2       31
# 7161           bc      2       31
# 7671          5th      1       31
# 7133           xi      1       31
# 8587       patron      1       31
# 9731   descendant      1       31
# 9609     namesake      1       31
# 9275        feast      1       31
# 7936       oldest      1       31
# 7795         1930      1       31
# 8732    centuries      1       31
# 9724       oxford      1       31
# 3720          8th      1       31
# 4635     founding      1       31
# 4543  grandfather      1       31
# 4024     kentucky      1       31
# 2096          6th      1       31
# 6196         18th      1       31
# 5950   alexandria      1       31
# 6787     basilica      1       31
# 6827         21st      1       31
# 6771         15th      1       31
#
# Cluster:  32
# 0.01584705040384419
# Average Word Count:  7.922580645161291
#             Word  Count  Cluster
# 4603     figures     94       32
# 5664     expects     69       32
# 435         rise     55       32
# 547      economy     51       32
# 810       growth     49       32
# 377       reduce     48       32
# 1616       gauge     45       32
# 1430    increase     31       32
# 474       levels     31       32
# 730       demand     28       32
# 1456        cost     27       32
# 1491      rising     26       32
# 4213         low     24       32
# 589    increased     22       32
# 736     trillion     21       32
# 1130      faster     19       32
# 2201         cut     19       32
# 539         zero     18       32
# 1329  increasing     18       32
# 1065       boost     17       32
# 864        below     16       32
# 538          net     16       32
# 1501      higher     14       32
# 2220         gap     14       32
# 1772     cutting     14       32
# 2912        grow     14       32
# 2942   economies     13       32
# 481         cuts     13       32
# 749      average     12       32
# 3930       costs     11       32
#
# Cluster:  33
# 0.012370923218484818
# Average Word Count:  1.7520661157024793
#                     Word  Count  Cluster
# 3020             retrain     46       33
# 2889         sustainably      7       33
# 6291       inefficiently      6       33
# 489           decisively      5       33
# 3885            aligning      5       33
# 3227            behaving      4       33
# 2639         subsidising      4       33
# 5629           trillions      4       33
# 5584        collectively      4       33
# 7920             agendas      3       33
# 8279  disproportionately      3       33
# 7841       nutritionally      2       33
# 9236        meaningfully      2       33
# 95         realistically      2       33
# 2316       exponentially      2       33
# 4577            commited      2       33
# 6610              rotate      2       33
# 6847              vested      2       33
# 9420          tirelessly      2       33
# 3715        inextricably      2       33
# 3600           radically      2       33
# 678              swiftly      2       33
# 7026             bridged      1       33
# 7507         fashionably      1       33
# 9443              upping      1       33
# 8770           subsisted      1       33
# 9562               woken      1       33
# 8857              cycled      1       33
# 7453     comprehensively      1       33
# 7489             steered      1       33
#
# Cluster:  34
# 0.009814947346897045
# Average Word Count:  3.8645833333333335
#             Word  Count  Cluster
# 1614        neat     45       34
# 1360       green     42       34
# 567        clean     39       34
# 427   atmosphere     19       34
# 734          add     13       34
# 2478        warm      8       34
# 3483      simple      8       34
# 290        dirty      8       34
# 952        stark      7       34
# 3683       black      6       34
# 3729        blue      6       34
# 6530        eyes      6       34
# 1414       usual      6       34
# 2829        rice      5       34
# 5226        gray      5       34
# 1549   fantastic      5       34
# 3114        grey      5       34
# 1498        lots      5       34
# 3174       solid      5       34
# 7255      sounds      4       34
# 6401    precious      4       34
# 649        fresh      4       34
# 1428   beautiful      4       34
# 1761         mix      4       34
# 1886       light      4       34
# 3329     strange      3       34
# 7028        wine      3       34
# 8334      beauty      3       34
# 8336        thin      3       34
# 6396       grown      3       34
#
# Cluster:  35
# 0.01635824557816174
# Average Word Count:  3.76875
#                  Word  Count  Cluster
# 718       sustainable     60       35
# 554        accelerate     28       35
# 728          reducing     27       35
# 2077     transparency     22       35
# 2921            adapt     18       35
# 2300         tackling     16       35
# 40            promote     14       35
# 2120          scaling     13       35
# 2176         ensuring     12       35
# 2008        achieving     12       35
# 212         transform     12       35
# 3025        improving     11       35
# 2323        promoting     10       35
# 1520       contribute     10       35
# 2384          enhance     10       35
# 5042          improve      9       35
# 1392         mobilize      9       35
# 4501         adapting      9       35
# 2128    strengthening      8       35
# 3706   sustainability      8       35
# 731         advancing      7       35
# 3348       protecting      7       35
# 2121       mobilizing      7       35
# 2343  multilateralism      6       35
# 2534          ramping      6       35
# 7516        enhancing      6       35
# 6210     transforming      5       35
# 5248         impacted      5       35
# 2164     contributing      5       35
# 5175     accelerating      5       35
#
# Cluster:  36
# 0.010735098660668643
# Average Word Count:  1.6
#                 Word  Count  Cluster
# 1368        alarming     11       36
# 3022     unstoppable     11       36
# 929         inaction      7       36
# 8154        suicidal      6       36
# 485     irreversible      6       36
# 2886         excuses      5       36
# 4394         morally      4       36
# 2202       premature      4       36
# 8267         immoral      4       36
# 7843        wasteful      2       36
# 5145        sobering      2       36
# 987       conflicted      2       36
# 4762           scary      2       36
# 2265     unavoidable      2       36
# 6587       ludicrous      2       36
# 7024          excuse      2       36
# 6821         grossly      2       36
# 7013    unacceptable      2       36
# 1335     spontaneous      2       36
# 4029     fascinating      2       36
# 3509        shocking      2       36
# 2828      disruptive      2       36
# 682   unsatisfactory      2       36
# 7536       intrusion      1       36
# 9454      heartening      1       36
# 7474       honorable      1       36
# 9514   underwhelming      1       36
# 7481       statistic      1       36
# 9653         fraught      1       36
# 7632         awkward      1       36
#
# Cluster:  37
# 0.006747776300991719
# Average Word Count:  2.8333333333333335
#            Word  Count  Cluster
# 5661   figueres     69       37
# 2         costa     12       37
# 4959  brazilian      5       37
# 6        carlos      4       37
# 4453         de      4       37
# 2950   espinosa      4       37
# 2116   guterres      4       37
# 5339     miguel      3       37
# 8974       zein      3       37
# 5995     mendes      3       37
# 7        manuel      3       37
# 3036       duda      3       37
# 3093   fernanda      3       37
# 3092      maría      3       37
# 7840       cruz      2       37
# 4454       alba      2       37
# 5140      vidal      2       37
# 1665     javier      2       37
# 1686      paola      2       37
# 3         rican      2       37
# 7007     romero      2       37
# 5994       josé      2       37
# 5947   bertrand      2       37
# 8644     duarte      2       37
# 3623    antonio      2       37
# 4355      bello      2       37
# 7522      santa      1       37
# 9705     thiago      1       37
# 9706     araujo      1       37
# 9649      pablo      1       37
#
# Cluster:  38
# 0.02453736836724261
# Average Word Count:  31.066666666666666
#              Word  Count  Cluster
# 171            we    974       38
# 162           our    489       38
# 161           you    482       38
# 361           how    342       38
# 157          need    303       38
# 325          just    257       38
# 205          what    207       38
# 784         learn    176       38
# 362            do    161       38
# 156             i    160       38
# 346            if    157       38
# 215         watch    146       38
# 530          make    136       38
# 149          your    128       38
# 131           see    108       38
# 478          says    106       38
# 389            so     98       38
# 744         every     93       38
# 240           why     93       38
# 943      tomorrow     80       38
# 360          know     71       38
# 613          good     65       38
# 169           way     64       38
# 168          find     63       38
# 3018        makes     61       38
# 1091          get     61       38
# 1088           my     58       38
# 64    opportunity     55       38
# 437          want     54       38
# 316          come     52       38
#
# Cluster:  39
# 0.01257540128821184
# Average Word Count:  4.495934959349594
#               Word  Count  Cluster
# 537      ambitious    121       39
# 1317          very     49       39
# 192     vulnerable     22       39
# 1930     resilient     22       39
# 1964          bold     13       39
# 693           safe     12       39
# 130       exciting     11       39
# 1786       pleased     10       39
# 6356         badly      9       39
# 8089   desperately      8       39
# 3836    optimistic      8       39
# 1724       neutral      8       39
# 1468    prosperous      8       39
# 2825      stronger      7       39
# 5312       healthy      7       39
# 713          smart      7       39
# 2002     difficult      7       39
# 72       seriously      7       39
# 1591         safer      7       39
# 529      concerned      6       39
# 498   increasingly      5       39
# 8394        mature      5       39
# 4657        deeply      5       39
# 1351   encouraging      5       39
# 3409     excellent      5       39
# 1966    productive      5       39
# 3059    compelling      5       39
# 1953      globally      5       39
# 5824     extremely      5       39
# 6882      balanced      4       39
#
# Cluster:  40
# 0.00695225437071874
# Average Word Count:  4.647058823529412
#            Word  Count  Cluster
# 374     million     51       40
# 371   thousands     31       40
# 1346        1.5     27       40
# 1736     nearly     21       40
# 1774        per     17       40
# 816    millions     14       40
# 2213  estimated      9       40
# 1773       tons      8       40
# 1457   hundreds      7       40
# 5508        200      7       40
# 4595     84,000      7       40
# 6252     tonnes      6       40
# 7107      1,000      6       40
# 1310       1000      5       40
# 336         150      5       40
# 4416     50,000      4       40
# 3745        900      4       40
# 2286        300      4       40
# 245         500      4       40
# 5843        1.8      4       40
# 8977      4,000      3       40
# 3558        400      3       40
# 4201     metric      3       40
# 4650        us$      3       40
# 3920    500,000      3       40
# 6612     20,000      3       40
# 4098      fewer      3       40
# 2229        1.3      3       40
# 7883     28,000      2       40
# 4540    roughly      2       40
#
# Cluster:  41
# 0.013086596462529394
# Average Word Count:  14.09375
#                 Word  Count  Cluster
# 223               un    221       41
# 209            talks    143       41
# 15         discussed    112       41
# 946        agreement     91       41
# 136     negotiations     81       41
# 295               eu     73       41
# 5663         outline     70       41
# 1099       implement     66       41
# 1824        progress     56       41
# 3017     declaration     55       41
# 19    implementation     52       41
# 2883       consensus     49       41
# 1366         nations     48       41
# 964      negotiators     37       41
# 2961           joint     36       41
# 814       initiative     31       41
# 1154      commitment     31       41
# 2302            deal     28       41
# 1327    implementing     21       41
# 912         dialogue     21       41
# 1362     commitments     20       41
# 1086     partnership     18       41
# 91          finalize     17       41
# 2995    multilateral     17       41
# 1497        solution     17       41
# 795        framework     17       41
# 6036     discussions     16       41
# 2378          unfccc     15       41
# 861            draft     15       41
# 1345         pledges     13       41
#
# Cluster:  42
# 0.014722421020345568
# Average Word Count:  11.229166666666666
#              Word  Count  Cluster
# 214         world    418       42
# 1529        event    217       42
# 86         record    109       42
# 337        worlds    107       42
# 483         goals     78       42
# 1233         play     48       42
# 382          goal     48       42
# 1554         race     39       42
# 1333          top     37       42
# 1556          win     32       42
# 449          lead     25       42
# 2603    challenge     24       42
# 1714         team     24       42
# 840          miss     21       42
# 116         final     19       42
# 823         kicks     19       42
# 2998         slot     16       42
# 1070      winners     11       42
# 2361       lineup     10       42
# 284           usa     10       42
# 1072  competition      9       42
# 2509     champion      8       42
# 7520       finish      8       42
# 4157    champions      8       42
# 8120         beat      8       42
# 1713      cycling      8       42
# 1340       double      8       42
# 3338       stakes      7       42
# 771         saved      7       42
# 188    australian      6       42
#
# Cluster:  43
# 0.01860750434515898
# Average Word Count:  2.401098901098901
#            Word  Count  Cluster
# 3201       room     30       43
# 1539     panels     27       43
# 2101        ice     15       43
# 3963      front     14       43
# 2786     inside     11       43
# 1288      table      9       43
# 1853     breaks      9       43
# 950    concrete      9       43
# 6285    covered      7       43
# 7461     window      7       43
# 4449      piece      7       43
# 2963    kicking      7       43
# 2152     thread      6       43
# 2520     packed      6       43
# 7094     walked      6       43
# 2480    burning      5       43
# 2438      hands      5       43
# 8776      clock      5       43
# 3463        tap      4       43
# 3897     chains      4       43
# 8933       wrap      4       43
# 511     plastic      4       43
# 5580   covering      4       43
# 2030       door      4       43
# 5189     plates      4       43
# 7621      shell      4       43
# 3368   barriers      3       43
# 8971      wings      3       43
# 3546  cardboard      3       43
# 8497    wearing      3       43
#
# Cluster:  44
# 0.013700030671710458
# Average Word Count:  3.3507462686567164
#            Word  Count  Cluster
# 364       david     57       44
# 363         sir     44       44
# 4430  scientist     39       44
# 1936   director     24       44
# 4568      perry     11       44
# 4080        ceo      9       44
# 4087        lee      8       44
# 224    marshall      8       44
# 490          dr      7       44
# 3658     arnold      6       44
# 646        mark      6       44
# 4490     muller      6       44
# 5225        ian      5       44
# 2500         mr      5       44
# 2328    downing      5       44
# 5362      peter      5       44
# 1675       john      4       44
# 7020     robert      4       44
# 6414       hans      4       44
# 3006      frank      4       44
# 1638       nick      4       44
# 1640      simon      4       44
# 7532      wells      4       44
# 5208     farmer      4       44
# 5528       marc      4       44
# 1089     friend      4       44
# 6342     pierre      4       44
# 5414      jason      3       44
# 3548    partner      3       44
# 5854       liam      3       44
#
# Cluster:  45
# 0.01748287496166036
# Average Word Count:  8.228070175438596
#                  Word  Count  Cluster
# 173             check    154       45
# 1405       transition    147       45
# 448               act    123       45
# 603              plan     64       45
# 20         guidelines     49       45
# 229            policy     38       45
# 966             rules     38       45
# 2703         policies     31       45
# 2044           ensure     29       45
# 545         necessary     24       45
# 2876            issue     24       45
# 508           process     23       45
# 1324         security     20       45
# 1804         requires     20       45
# 5851        effective     18       45
# 2078        reporting     18       45
# 1251            limit     18       45
# 6834          charter     17       45
# 1321           motion     17       45
# 1470         benefits     15       45
# 1260          adopted     14       45
# 956             phase     14       45
# 1509         schedule     13       45
# 4376         blocking     12       45
# 806           setting     12       45
# 1326            order     12       45
# 3888  recommendations     11       45
# 803              term     11       45
# 4019        emergency     10       45
# 3080             rule     10       45
#
# Cluster:  46
# 0.011859728044167264
# Average Word Count:  2.646551724137931
#           Word  Count  Cluster
# 2001     heres     39       46
# 9105   valérie     36       46
# 2962       mdb     24       46
# 3780  thunberg     15       46
# 2569    timoci     12       46
# 1005     arent     12       46
# 3503      shes      6       46
# 7131   petteri      6       46
# 202        wri      5       46
# 7518     wisla      4       46
# 6341   cyrille      4       46
# 4715     narew      3       46
# 4121      icat      3       46
# 5187     a.k.a      3       46
# 1605      incl      3       46
# 3094    garcés      3       46
# 2501    macron      2       46
# 8047       gcf      2       46
# 5288  ondemand      2       46
# 7839   earlene      2       46
# 5139    pulgar      2       46
# 8190    haiyan      2       46
# 7272    cañete      2       46
# 7217       tmw      2       46
# 1649    ilaria      2       46
# 1699  emanuela      2       46
# 1683    pilita      2       46
# 6823       mtg      2       46
# 6937    nugzar      2       46
# 6909      govs      2       46
#
# Cluster:  47
# 0.01738063592679685
# Average Word Count:  3.3529411764705883
#                Word  Count  Cluster
# 1386      explainer     48       47
# 977        rulebook     41       47
# 237         netzero     37       47
# 876           whats     33       47
# 811        longterm     28       47
# 1250           ipcc     28       47
# 239           thats     27       47
# 2741         theres     24       47
# 411             wmo     21       47
# 1742        warmest     13       47
# 4439            u.n     11       47
# 3151  civilisations      7       47
# 3247            hes      7       47
# 4592         nargis      7       47
# 3751           reps      6       47
# 4169       phaseout      6       47
# 1602      marrakech      5       47
# 4882            ive      5       47
# 1153        canadas      5       47
# 7767        africas      5       47
# 609          earths      5       47
# 1245        sceptic      5       47
# 4974         chinas      4       47
# 2312      childrens      4       47
# 5281        endgame      4       47
# 5476  mainstreaming      4       47
# 8976          yalla      3       47
# 4266      tomorrows      3       47
# 5077         bolder      3       47
# 2348       fracking      3       47
#
# Cluster:  48
# 0.006441059196401186
# Average Word Count:  1.9047619047619047
#             Word  Count  Cluster
# 8298       18.45     17       48
# 1252          2c     13       48
# 2419   gigawatts      5       48
# 3877       13.15      4       48
# 7752       15.30      4       48
# 6377       15.00      4       48
# 6488         430      3       48
# 1789         214      3       48
# 5176         330      2       48
# 6733         314      2       48
# 6231         bln      2       48
# 7381         195      2       48
# 7452         930      2       48
# 2671  households      2       48
# 8650       14.50      2       48
# 8928         133      2       48
# 4200        22.4      2       48
# 4203        35.8      2       48
# 2840       11.35      2       48
# 8834       18.30      2       48
# 7503         189      1       48
# 9702         1,5      1       48
# 8843         415      1       48
# 9009          ft      1       48
# 7622         122      1       48
# 8914         355      1       48
# 8913         123      1       48
# 9481       1,024      1       48
# 9466         138      1       48
# 8318         129      1       48
#
# Cluster:  49
# 0.010837337695532153
# Average Word Count:  1.9150943396226414
#                    Word  Count  Cluster
# 523      transformative     13       49
# 2129         frameworks     10       49
# 8612           powering      8       49
# 949              unlock      7       49
# 2122          unlocking      7       49
# 6127           catalyze      6       49
# 1403           pathways      5       49
# 5547  intergenerational      5       49
# 6695          silencing      4       49
# 1348      replenishment      4       49
# 5982            ticking      4       49
# 7679            pathway      4       49
# 8835          modelling      3       49
# 7047              queue      3       49
# 4465       complemented      3       49
# 1931           adaptive      3       49
# 2420              grids      3       49
# 2592         decoupling      3       49
# 8019                ccs      2       49
# 7919          connector      2       49
# 9288           firewall      2       49
# 8105    transformations      2       49
# 8207      abbreviations      2       49
# 6542          coherence      2       49
# 6609             busses      2       49
# 7305      participatory      2       49
# 1499               meps      2       49
# 6997        incremental      2       49
# 6998   transformational      2       49
# 7077         converging      2       49

# %%
# More detail about a specific cluster

freq_analysis_df[freq_analysis_df["Cluster"]==26].head(50)
# Out:
#                 Word  Count  Cluster
# 1062             hub     42       26
# 158              air     35       26
# 1766       transport     30       26
# 1912          launch     26       26
# 3713        vehicles     23       26
# 1896       launching     14       26
# 179          driving     14       26
# 1152            ramp     13       26
# 2371           train     12       26
# 2751         powered     10       26
# 2380            mine     10       26
# 544   transportation     10       26
# 3894         vehicle      8       26
# 1722            bike      7       26
# 3775        shipping      7       26
# 3774        maritime      7       26
# 2370        arriving      7       26
# 3773         flights      7       26
# 3207      operations      6       26
# 3634            cars      6       26
# 2669         station      6       26
# 1080          travel      5       26
# 6716          landed      5       26
# 5262             fly      5       26
# 7861         landing      5       26
# 2108            duty      5       26
# 6928           crash      4       26
# 4199          driver      4       26
# 4844           canoe      4       26
# 5850           craft      4       26
# 5762         spotted      3       26
# 4758         airport      3       26
# 4466         transit      3       26
# 7162          guided      3       26
# 8008        launches      3       26
# 5209          riding      3       26
# 4052        speeding      3       26
# 1352         arrives      3       26
# 832          mission      3       26
# 2473            ride      2       26
# 2143         departs      2       26
# 5567         service      2       26
# 2045        deployed      2       26
# 2519          trains      2       26
# 4846     destination      2       26
# 2291        departed      2       26
# 2374            boat      2       26
# 5868         piloted      2       26
# 5781           buses      2       26
# 5779        airports      2       26

# %% [markdown]
# ### PCA Visualisation of Lexicon Clusters

# %%
# Compute first three principal components of word embedding data

from sklearn.decomposition import PCA
pca = PCA(n_components=3)
embedding_matrix_pc = pca.fit_transform(embedding_matrix)
freq_analysis_df["PC1"] = embedding_matrix_pc[:,0]
freq_analysis_df["PC2"] = embedding_matrix_pc[:,1]
freq_analysis_df["PC3"] = embedding_matrix_pc[:,2]

# %%
pca.explained_variance_ratio_
# Out:
# array([0.13975477, 0.04460236, 0.03663856])

# %%
# Function to make colormap of scatter plots uniform

def scatter_cmap(colours):
    colours_unique = list(set(colours))
    colours_unique.sort()
    n = len(colours_unique)
    colours_scaled = []
    for c in colours:
        colours_scaled.append(colours_unique.index(c)/n)
    return colours_unique, colours_scaled

# %%
# Filter dataframe for plotting

freq_analysis_df_filtered = freq_analysis_df[freq_analysis_df["Cluster"].isin([17,21,25,26]) & (freq_analysis_df["Count"]>0)]

# %%
# 2D PC Plot

colours_unique, colours_scaled = scatter_cmap(list(freq_analysis_df_filtered["Cluster"]))

plt.figure(figsize=(16,16))
scatter = plt.scatter(freq_analysis_df_filtered["PC1"],
            freq_analysis_df_filtered["PC2"],
            c=colours_scaled,
            cmap = "plasma")
handles, labels = scatter.legend_elements()
plt.legend(handles, colours_unique)
plt.show()

# %%
# 3D PC Plot

fig = plt.figure(figsize=(16,16))
ax = fig.add_subplot(projection='3d')

colours_unique, colours_scaled = scatter_cmap(list(freq_analysis_df_filtered["Cluster"]))

scatter = ax.scatter(freq_analysis_df_filtered["PC1"],
           freq_analysis_df_filtered["PC2"],
           freq_analysis_df_filtered["PC3"],
           c=colours_scaled,
          cmap = "plasma")

handles, labels = scatter.legend_elements()
plt.legend(handles, colours_unique)

ax.view_init(30, 30)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# ## Tweet-Level Analysis

# %% [markdown]
# ### Clustering by number of words per word-cluster

# %%
# Score each tweet by the word-clusters

tweets_df["Content Cleaned"] = tweets_clean
word_cluster_dict = dict(zip(list(freq_analysis_df["Word"]),list(freq_analysis_df["Cluster"])))
word_cluster_matrix = np.zeros((len(tweets_df),num_clusters_words))
for k in range(num_clusters_words):
    word_cluster_col = tweets_df["Content Cleaned"].apply(lambda x: sum([word_cluster_dict[word] == k for word in x.split()]))
    tweets_df["C"+str(k)] = word_cluster_col
    word_cluster_matrix[:,k] = np.array([word_cluster_col])

# %%
# Agglomerative Clustering for tweets

num_clusters_tweets = 12
clustering_agg_tweets = AgglomerativeClustering(n_clusters=num_clusters_tweets, distance_threshold=None, affinity="chebyshev", linkage = "complete").fit(normalize(word_cluster_matrix, axis=1, norm="l1"))
tweets_df["Cluster"] = clustering_agg_tweets.labels_

# %%
clustering_agg_tweets.n_clusters_
# Out:
# 1

# %%
plot_dendrogram(clustering_agg_tweets, truncate_mode="level", p=5)

# %%
# K-Means Clustering for tweets

num_clusters_tweets = 20
clustering_kmeans_tweets = KMeans(n_clusters=num_clusters-1, random_state=0, n_init=10).fit(normalize(word_cluster_matrix, axis=1, norm="l1"))
tweets_df["Cluster"] = clustering_kmeans_tweets.labels_

# %% [markdown]
# ### Average Embedding Vector Clustering

# %%
# Create an average embedding vector for each tweet
# Ignore stop words

tweet_sequences = tokenizer.texts_to_sequences(tweets_clean)
stop_words_tokens = tokenizer.texts_to_sequences([stop_words])[0]

tweet_embedding_avg_matrix = np.zeros((len(tweets_df), 100))
for i in range(len(tweets_df)):
    vector_sum = np.zeros(100)
    for token in tweet_sequences[i]:
        # Ignore stop words - may make agglom. clustering impossible with cosine similarity
        if token not in stop_words_tokens:
            vector_sum += embedding_matrix[token - 2]
    tweet_embedding_avg_matrix[i] = vector_sum
tweet_embedding_avg_matrix = normalize(tweet_embedding_avg_matrix, axis=1)
tweets_df = pd.concat([tweets_df,
                                 pd.DataFrame(data=tweet_embedding_avg_matrix, columns=["ec"+str(i) for i in range(100)])],
                                 axis=1)

# %%
# Average embedding vector clustering (agglomerative)

num_clusters_tweets = 8
kmeans_tweets_avg = KMeans(n_clusters=num_clusters_tweets, random_state=0, n_init=10).fit(tweet_embedding_avg_matrix)
tweets_df["Cluster"] = kmeans_tweets_avg.labels_

# %%
# Average embedding vector clustering (agglomerative)

num_clusters_tweets = 8
clustering_agg_tweets_avg = AgglomerativeClustering(n_clusters=None, distance_threshold=0.1,
                                                    linkage="complete", affinity="cosine").fit(tweet_embedding_avg_matrix)
tweets_df["Cluster"] = clustering_agg_tweets_avg.labels_
#tweets_df["Cluster Distance"] = [np.linalg.norm(tweet_embedding_avg_matrix[i] - clustering_agg_tweets_avg.cluster_centers_[tweets_df["Cluster"][i]]) for i in range(len(tweets_df))]

# %%
plot_dendrogram(clustering_agg_tweets_avg, truncate_mode="level", p=10)

# %% [markdown]
# ### Cluster Exploration

# %%
# Display information about each cluster

for k in range(num_clusters_tweets):
    print("\nCluster: ",k)
    cluster_df = tweets_df[tweets_df["Cluster"]==k]
    print("Fraction of Data: ", len(cluster_df)/len(tweets_df))
    print("Average Likes: ", np.mean(cluster_df["Likes"]))
    for i in range(3):
        if i< len(cluster_df):
            print(cluster_df.sort_values(by="Likes", ascending=False).iloc[i,9])
# Out:
# Cluster:  0
# Fraction of Data:  0.007321881160236553
# Average Likes:  127.38461538461539
# Greetings from Poland!
# #COP24 https://t.co/D8glTRrAJq
# Quite a frontpage in the Daily Mirror this morning...
#
# #COP24 https://t.co/RB2poNueAu
# Efficient solutions are wins for
# ✅ people
# ✅ planet
# ✅ profit
# Our Ambassador @bertrandpiccard of @solarimpulse delivers a powerful message to #COP24 https://t.co/sZuog0ovOr
#
# Cluster:  1
# Fraction of Data:  0.1954379048155449
# Average Likes:  252.69164265129683
# "Climate change is not the concern of just one or two nations. It is an issue that affects the whole of humanity and every living being on this earth." (From HHDL's Message to Delegates to the COP24 UN Climate Conference https://t.co/GEbUIOEPIl)
# "We're facing a man-made disaster of global scale... time is running out" - Sir David Attenborough issues warning at UN Climate Conference #COP24 in Poland https://t.co/I8q5wKRm3v https://t.co/e2GlRChign
# The UN Climate Conference is our last best chance to stop runaway climate change. This is the time for consensus. #ClimateAction will benefit us all collectively. My appeal to #COP24: https://t.co/Z6wJq2AQ2v https://t.co/36rxDBwC0Q
#
# Cluster:  2
# Fraction of Data:  0.20529428330047875
# Average Likes:  96.47050754458162
# Despite Trump, More Signs Coal Power’s Future Actually Looks Terrible in the US #uspoli #climatechange #COP24
#
# https://t.co/bdOQMrNJWb https://t.co/lkmuewMRFA
# We are the first generation to broadly experience the impacts of climate change.
#
# We are the first generation to understand the solutions and have a commitment to each do our part.
#
# We are the last generation who can prevent the worst effects.
#
# So let's do it. #COP24
# Greta Thunberg: "You are not mature enough to tell it like it is. Even that burden you leave to us children" #FridaysForFuture #ClimateStrike #ClimateChallenge #ClimateLeader #cop24 #schoolstrike4climate https://t.co/9XQblo3N6Q
#
# Cluster:  3
# Fraction of Data:  0.09152351450295691
# Average Likes:  126.6923076923077
# As soon as our politicians, the media and our society start treating the climate crisis as the crisis it is, we will no longer need climate conferences like the #cop24. Because then all our time will be spent on cutting emissions and changing our society into a sustainable one.
# We bought the naming rights for a caecilian that can only see light and dark at @RainforestTrust's charity auction. @RealDonaldTrump must see the world in black &amp; white to think climate change is a hoax; he’s a perfect namesake! #COP24 #charitytuesday https://t.co/497929Dklk https://t.co/xD2YXxBJ3W
# The approval of the #ParisAgreement Work Programme at #COP24 in Katowice is the foundation for a new process in #ClimateAction.
#
# Ambition will be at the centre of the Climate Summit I am convening in September. It's time to show strengthened ambition to defeat climate change.
#
# Cluster:  4
# Fraction of Data:  0.11405237961137708
# Average Likes:  131.18765432098766
# In Turkey they're using wind from passing busses to rotate wind vanes and #solar panels creating electricity to power 20,000 homes.
#
# We have the solutions to the #climate crisis. The only thing missing is the political will to implement them
#
# ⁠#ActOnClimate #tech #COP24 #climate https://t.co/f41M0CdD50
# David Attenborough warned at #COP24 that collapse of civilisations &amp; natural world are on horizon.
#
# So I asked Prime Minister why she's still subsidising fossil fuels.
#
# Her response? Vague muttering about wanting an 'energy mix'. The ignorance at the top of our Govt is shocking. https://t.co/69TniacUmc
# Goosebumps! 15 year old activist @GretaThunberg speaks truth to power at the UN #COP24 climate talks: "You say you love your children above all else, and yet you're stealing their future before their very eyes." https://t.co/FfVhdyC7tH
#
# Cluster:  5
# Fraction of Data:  0.2278231484088989
# Average Likes:  175.44993819530285
# ”So we have not come here to beg the world leaders to care for our future. They have ignored us in the past and they will ignore us again.
# We have come here to let them know that change is coming whether they like it or not.”
#
# From my speech yesterday at #COP24 https://t.co/WIwv4vbT6G
# "You say you love your children above all else and yet, you're stealing their future in front of their very eyes."
#
# 15-year-old @GretaThunberg speaks at #COP24. https://t.co/0Ex5dpNVUa
# Here is my full speech from UN #cop24 plenary, in print! #ClimateStrike  #SchoolStrike4Climate #FridaysForFuture https://t.co/L9vwPbgY0s
#
# Cluster:  6
# Fraction of Data:  0.019994367783722895
# Average Likes:  0.28169014084507044
# If we are to secure the promise of the #ParisAgreement &amp; protect #nature &amp; people, #ClimateAction must be accelerated! #COP24
#
# #March4Climate
# #MarchCOP24
# #WWFClimate https://t.co/PrYgT8VkA7
# @UN @antonioguterres #WWFClimate #COP24 updates: https://t.co/JCajrTDByu
# @MartaOlender COP24 Must Read: Christiana Figueres et al outline how the world expects governments to respond to record emissions figures https://t.co/qPCLettdoI https://t.co/oVhV6ltSvR
#
# Cluster:  7
# Fraction of Data:  0.138552520416784
# Average Likes:  218.46747967479675
# “You say you love your children above all else and yet, you're stealing their future in front of their very eyes.”
#
# @gretathunberg calling out world leaders at #COP24. Let's hope they take her powerful message to heart before it's too late. https://t.co/pHtI0tmG1F
# ”You are not mature enough to tell it like it is. Even that burden you leave to your children.”
#
# Here’s my full speech in front of the UN plenary at #COP24 .
# https://t.co/f0gxp0h3i2
#
# #ClimateStrike #FridaysForFuture #SchoolStrike4Climate #ClimateJustice https://t.co/aDhqNrlSIp
# The toughest thing for me in space is knowing that only a few humans will ever see our planet like this. It will be essential for our species to eventually to change that. #Horizons #COP24 https://t.co/jUMXF1bVvK

# %%
# Tweets from a specific cluster

list(tweets_df[tweets_df["Cluster"]==7].sort_values(by="Likes", ascending=False)["Content"].iloc[:50])
# Out:
# ["“You say you love your children above all else and yet, you're stealing their future in front of their very eyes.”\n\n@gretathunberg calling out world leaders at #COP24. Let's hope they take her powerful message to heart before it's too late. https://t.co/pHtI0tmG1F",
#  '”You are not mature enough to tell it like it is. Even that burden you leave to your children.” \n\nHere’s my full speech in front of the UN plenary at #COP24 .\nhttps://t.co/f0gxp0h3i2\n\n#ClimateStrike #FridaysForFuture #SchoolStrike4Climate #ClimateJustice https://t.co/aDhqNrlSIp',
#  'The toughest thing for me in space is knowing that only a few humans will ever see our planet like this. It will be essential for our species to eventually to change that. #Horizons #COP24 https://t.co/jUMXF1bVvK',
#  'This is what we have to do. This is what have to focus on every hour of every day. This is everybody’s moral duty. Starting today. #COP24 https://t.co/1aVMCYOSEk',
#  'Sir David Attenborough at #COP24: "If we don’t take #ClimateAction, the collapse of our civilisations and the extinction of much of the natural world is on the horizon." #TakeYourSeat https://t.co/kjbUvLntBf',
#  'What would you say if you had a seat at the @UN #ClimateChange Conference #COP24 in Poland in December? Share your comments, videos and photos with #TakeYourSeat to have your say &gt; https://t.co/9CzZFynwya #ClimateAction https://t.co/J4WNEi4c5A',
#  'A few days before I went to Katowice and #cop24 I made a TEDx talk in Stockholm. Here it is! \n\nhttps://t.co/UBVc2roHMz\n\n#ClimateStrike #SchoolStrike4Climate #FridaysForFuture https://t.co/r4zg7hRxHG',
#  'How the world sees Scotland: Watch former US Vice-President @algore interview First Minister @NicolaSturgeon about enlightened Scottish environmental policy #COP24 #ClimateAction 🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f🌍 https://t.co/Xm0135M0PJ',
#  "This is what polluted air can do to a child's brain.\n\n@UNICEF_Mongolia #COP24 https://t.co/LhAD541qtG",
#  'Jason, You should have asked me. I was at COP24 for work, took the train for 2 days to get to Italy to see my son and daughter in law who are there on Sabbatical. You know me. I walk the talk. Elizabeth https://t.co/rg5ye5LMrc',
#  "We risk losing our soils to an invisible threat - soil pollution.\n\n📽️ Watch to find out why we can't let this happen 👇 \n\n#WorldSoilDay #StopSoilPollution #ZeroHunger #COP24 https://t.co/PYRyk8WhIt",
#  "At #COP24, leaders must agree on the 'Paris Rulebook' to bring the historic #ParisAgreement fully to life. Watch this video explainer and read our new blog to learn more: https://t.co/M4woaCdiq6  @UNFCCC @COP24 @ClimateHome  #climate @YDagnet @NathanCogswell https://t.co/wmtI6AAq5Q",
#  'Last year, Timoci inspired millions with his passionate speech on #ClimateChange.\n\nNow, as world leaders meet for #COP24, Timoci’s plea is more urgent than ever. https://t.co/5558SjR4DU',
#  'President @MBuhari has departed Poland and is on his way back to Abuja, after attending and participating in #COP24Katowice.\n #COP24 #PMBinPoland',
#  'Students from @Cornell shared their experience holding a local #TalanoaDialogue in Ithaca NY at #COP24. Student Rhea Lopes emphasized the creativity &amp; adaptability of #Talanoa4Ambition - a place to bring empathy &amp; understanding to the process.  \n\nMore: https://t.co/AJEi4jcdF4 https://t.co/iBkouAwWXh',
#  'Today I’m at the :\nAction Hub with @UNFCCC 13:00\n\nPanel talk at World Bank “Youth unstoppable” at 14:00 Area E\n\nPress conference with Extinction Rebellion and Scientists Warning 15:00 Area F  \n#COP24',
#  'Watch Sir David Attenborough deliver collective thoughts on #ClimateChange to world leaders https://t.co/K7TFKrLIvz #COP24 #TakeYourSeat https://t.co/whrJ0j2wp1',
#  'Join the Talanoa Call for Action! #TakeYourSeat with Greta and Timoci in urging world leaders to step up #ClimateAction \nhttps://t.co/g0q66JjGzq\n#COP24 https://t.co/gpyelT4RUK',
#  '#ClimateChange has a disproportionately heavy toll on the wellbeing and rights of women &amp; girls. \n\nMore gender-responsive #ClimateAction will support the #JustTransition, promote #SustainableDevelopment, and reduce poverty. \n\n@UNHumanRights Chief @MBachelet 📢 #ActOnTheGAP #COP24 https://t.co/DPGgqQrziX',
#  'The official opening ceremony of @UN #ClimateChange Conference #COP24 in Katowice is about to begin. Live webcast: https://t.co/pVgL7b5vxB #ParisAgreement #ClimateAction https://t.co/UAFZVyN21E',
#  'Sir David Attenborough says that we’re facing a man-made disaster on a global scale. https://t.co/mnv5BLTo72 Via @ReutersTV #COP24 https://t.co/pz3Pxz9Q1e',
#  "If we don't take #action, the collapse of our civilisations and the #extinction of much of the natural world is on the horizon. - Sir David Attenborough\n@UNFCCC @BBCEarth #climatechange @UN #COP24 https://t.co/jBdJQYfprf",
#  '#COP24 ended with the adoption of the guidelines to unleash the full potential of the #ParisAgreement. Typhoon-survivor Joanna Sustento told us what it would mean to her to reach the agreement`s goals. #TakeYourSeat &amp; tell us: What would it mean to you? #ClimateChange https://t.co/GY6x8XuAgZ',
#  'What would u say if u had a seat at the UN #ClimateChange Conference #COP24 next week? Record your message with #TakeYourSeat to have your say. https://t.co/STlvqGh1Nc',
#  'We all know that ongoing #ClimateChange is already causing negative health effects &amp; undermining the “right to health” represented in the #ParisAgreement. Meeting the mitigation goals of the agreement would save millions of lives by 2050. https://t.co/7CXG2JFZFf #COP24 https://t.co/U20s7eEAiW',
#  'The food on the menu at #COP24 could emit the same amount of greenhouse gases as burning 500,000 gallons of gasoline, non-profits say https://t.co/zHi7W5Olwz',
#  'Youth champions Timoci from Fiji &amp; Hanna from Poland call for everyone to take #ClimateAction to achieve the #ParisAgreement climate goals. "Talanoa Call for Action" info: https://t.co/TdKIgpFON5  #COP24 via @UNFCCC https://t.co/8XPgdJi8lR',
#  'Young people are asking policy makers to implement the #ParisAgreement so we can all live on a healthy planet with a secure &amp; prosperous future -- @UNYouthEnvoy at #COP24 https://t.co/totxzdZPc4 https://t.co/ch0epDbbwc',
#  'Is #climatechange something YOU care about? We talk #COP24 and our own investments for #climate funding in this edition of #WBInsider. Watch: https://t.co/Jd8Wzk2lTB',
#  'What would you say if you had a seat at the @UN #ClimateChange Conference #COP24 next week? https://t.co/9CzZFynwya Please record your video message with #TakeYourSeat to have your say. https://t.co/quqW5iZri2',
#  'The second part of the high-level segment of the @UN #ClimateChange Conference #COP24 has begun. Watch the live webcast &gt;&gt; https://t.co/tgBay6tB9x  #ParisAgreement #TakeYourSeat https://t.co/5vXfFQLbCP',
#  '#ClimateChange disproportionately affects wellbeing &amp; rights of women &amp; girls. \n\nGender-responsive #ClimateAction will support the #JustTransition, promote #SustainableDevelopment, and reduce poverty. \n\n@UNHumanRights Chief @MBachelet 📢 #StandUp4HumanRights #ActOnTheGAP #COP24 https://t.co/WrMaNnqj38',
#  'Check out ways to virtually join the @UN #ClimateChange Conference #COP24 in Katowice which starts 2 December, including via live webcast https://t.co/khOuPstQIs #ParisAgreement #ClimateAction https://t.co/azTKB4zIek',
#  'Thank you to youth champions Timoci Naulusala from Fiji and Hanna Wojdowska from Poland for delivering the Talanoa Call for Action at #COP24 https://t.co/yUWL1Ji1ll #TakeYourSeat #JustTransition https://t.co/dEllPaTjJP',
#  'Thank you to the #G20 for your strong statement of support for a successful outcome of the @UN #ClimateChange Conference #COP24 https://t.co/fmUWylkdx2 #ParisAgreement #Talanoa4Ambition #G20Argentina https://t.co/6NXYJayDIe',
#  'Today, Governor @Schwarzenegger will inaugurate the #ClimateAction Hub!  #COP24 President @KurtykaMichal himself will then moderate the conversation with Hindu Ibrahim, Indigenous Leader. Join us at the #ActionHub at 15.15! https://t.co/GsTbEALFTd',
#  "A staggering 93% of the world's children are breathing dangerously polluted air.\n\nWe're calling on leaders at #COP24 to urgently reduce air pollution. It's time to replace fossil fuel combustion with cleaner, renewable sources of energy. https://t.co/mIekzUEmlj",
#  'The #WeDontHaveTime soundtrack. \nLet all world leaders hear this song before #COP24\n\nWe Don´t Have Time to wait!\n\nPlease share and RT! \n\nOn Spotify: https://t.co/h0NTOW92gD https://t.co/pkkL3XYkTf',
#  "This Syrian 🚴\u200d♀️initiative won a @Momentum_UNFCCC award at #COP24 for challenging gender stereotypes and promoting youth &amp; women's empowerment as well as #ClimateAction. https://t.co/1hxCwuCMTa https://t.co/fqfffjOtGU",
#  'As delegates take a break from official #ClimateChange negotiations today, take a look back at the best photos from the first week of #COP24 in #Katowice. More photos: https://t.co/lrJOVTReBG #ParisAgreement #ClimateAction https://t.co/raf7pUZaU2',
#  'Activists in Slovakia call for an End to the era of coal. Thank you! You are my #ReasonsForHope #COP24 #EndCoal #ClimateAction https://t.co/uwidJODTtc',
#  "#COP24 #TakeYourSeat #ExtinctionRebellion\n\n@BBCNews are a gov't puppet\n\nCoal miners in Poland &amp; the USA are dying of black lung:\nhttps://t.co/7qFwxltVtK\n\nIf you believe BBC News, #AirPollution must have lowered your IQ to such an extent that you are unable to think critically 🤔 https://t.co/LIssQ9mIUo",
#  'The @UN #ClimateChange conference #COP24 is only a few days away. Find all information here: https://t.co/ymbst09Mn0 https://t.co/pwMJQbXD6q',
#  'President Nasheed, the former President of the Maldives, is wearing our badge at #COP24. He just got asked to take if off, but refused. #ThisIsAnEmergency #RebelForLife https://t.co/i7o8gfWYN4',
#  'Meeting with the VP of #ADB @ADBClimate n their financial team COP24 to discuss #ClimateFinance in #Pakistan https://t.co/0QGwlveV7j',
#  'Reaching the goals of the #ParisAgreement is still possible, but all actors need to be onboard to make it happen. #ClimateAction #COP24 https://t.co/1xtSdh4kOK',
#  'Speaking at #IPCC #WMO #UNEP joint meeting at @COP24 - #Pakistan is doing more than it’s share n world is acknowledging #BillionTreeTsunami https://t.co/lHhVwMKB9r',
#  '#COP24 plenary has resumed. Watch the live webcast here &gt;&gt; https://t.co/E1cTabPShV #ParisAgreement #GlobalGoals #TakeYourSeat https://t.co/tVk29VzKVL',
#  'President of Poland Andrzej Duda at #COP24 ceremonial opening: The @UN #ClimateChange conference is now taking place on the exact location of where a #coal mine was once operated. Katowice is meanwhile one of the greenest cities in Poland. That is highly symbolic. #ParisAgreement https://t.co/wWj9QKNhXX',
#  'The most vulnerable, including women and children, are disproportionally affected by #ClimateChange. That is why gender mainstreaming is essential to achieve the goals of the #ParisAgrement https://t.co/P2IucK5tYZ @CarolaSchmidtZ @mmachile #ActOnTheGAP #COP24 https://t.co/AHxbT3qKGJ']

# %%
# Group tweets_df by category and cluster

tweets_cat_clust_df = pd.DataFrame(tweets_df["Date"].unique())
tweets_cat_clust_df = tweets_cat_clust_df.merge(pd.DataFrame(tweets_df["Category"].unique()), how="cross")
tweets_cat_clust_df = tweets_cat_clust_df.merge(pd.DataFrame(tweets_df["Cluster"].unique()), how="cross")
tweets_cat_clust_df = pd.DataFrame(np.array(tweets_cat_clust_df),
                                   columns = ["Date", "Category", "Cluster"])
tweets_cat_clust_df = tweets_cat_clust_df.merge(tweets_df.groupby(["Date", "Category", "Cluster"]).count().rename(columns={"ID":"Count"})["Count"],
                                                how="left", on=["Date", "Category", "Cluster"])
tweets_cat_clust_df = tweets_cat_clust_df.merge(tweets_df.groupby(["Date", "Category", "Cluster"]).sum()["Likes"],
                                                how="left", on=["Date", "Category", "Cluster"])
tweets_cat_clust_df.fillna(0,inplace=True)
tweets_cat_clust_df.sort_values(by = ["Date", "Category", "Cluster"], inplace=True)
tweets_cat_clust_df.reset_index(inplace=True)
tweets_cat_clust_df
# Out:
#       index        Date   Category  Cluster  Count  Likes
# 0        30  2018-11-15   Activist        0    0.0    0.0
# 1        24  2018-11-15   Activist        1    0.0    0.0
# 2        25  2018-11-15   Activist        2    0.0    0.0
# 3        27  2018-11-15   Activist        3    0.0    0.0
# 4        28  2018-11-15   Activist        4    0.0    0.0
# ...     ...         ...        ...      ...    ...    ...
# 3235   3203  2018-12-30  Scientist        3    0.0    0.0
# 3236   3204  2018-12-30  Scientist        4    0.0    0.0
# 3237   3202  2018-12-30  Scientist        5    0.0    0.0
# 3238   3207  2018-12-30  Scientist        6    0.0    0.0
# 3239   3205  2018-12-30  Scientist        7    0.0    0.0
#
# [3240 rows x 6 columns]

# %%
# Total tweet counts time series

plt.figure(figsize=(16,12))
bar = sns.barplot(data=tweets_cat_clust_df.groupby(["Date"]).sum().reset_index(), x="Date", y="Count", color="blue", ci=None, )
bar.set_xticklabels(bar.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.title("Total tweets across time")
plt.axvline(16, 0, 0.95 , color="black", linestyle="--")
plt.axvline(29, 0, 0.95 , color="black", linestyle="--")
plt.text(16, 310, "Start of conference")
plt.text(29, 310, "End of conference")
plt.show()

# %%
# Total tweet likes time series

plt.figure(figsize=(16,12))
bar = sns.barplot(data=tweets_cat_clust_df.groupby(["Date"]).sum().reset_index(), x="Date", y="Likes", color="red", ci=None, )
bar.set_xticklabels(bar.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.title("Total tweets across time")
plt.axvline(16, 0, 0.95 , color="black", linestyle="--")
plt.axvline(29, 0, 0.95 , color="black", linestyle="--")
plt.text(16, 90000, "Start of conference")
plt.text(29, 90000, "End of conference")
plt.show()

# %%
# Count of Tweets Across Time by Cluster

plt.figure(figsize=(18,16))
g = sns.FacetGrid(tweets_cat_clust_df.groupby(["Date","Cluster"]).sum().reset_index(),
                  row="Cluster", aspect=5, margin_titles=True, sharey=True)
g.map(sns.barplot, "Date", "Count", ci=None, color="blue")
g.fig.suptitle("Count of tweets across time by cluster")
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Tweet Likes Across Time by Cluster

plt.figure(figsize=(18,16))
g = sns.FacetGrid(tweets_cat_clust_df.groupby(["Date","Cluster"]).sum().reset_index(),
                  row="Cluster", aspect=5, margin_titles=True, sharey=True)
g.map(sns.barplot, "Date", "Likes", ci=None, color="red")
g.fig.suptitle("Count of tweets across time by cluster")
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Tweet Counts Across Time by Category

plt.figure(figsize=(18,16))
g = sns.FacetGrid(tweets_cat_clust_df.groupby(["Date","Category"]).sum().reset_index(), row="Category", aspect=5, margin_titles=True, sharey=True)
g.map(sns.barplot, "Date", "Count", ci=None, color="blue")
g.fig.suptitle("Count of tweets across time by category")
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Tweet Likes Across Time by Category

plt.figure(figsize=(18,16))
g = sns.FacetGrid(tweets_cat_clust_df.groupby(["Date","Category"]).sum().reset_index(), row="Category", aspect=5, margin_titles=True, sharey=True)
g.map(sns.barplot, "Date", "Likes", ci=None, color="red")
g.fig.suptitle("Count of tweets across time by category")
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Cluster-Category co-occurence matrices

plt.figure(figsize=(16,18))

plt.subplot(221)
plt.title("Frequency")
heat = sns.heatmap(tweets_df.pivot_table(values="ID",index="Cluster",columns="Category",aggfunc="count").fillna(0.0), annot=True, fmt="g")
heat.set_xticklabels(heat.get_xticklabels(), rotation=45, horizontalalignment='right')

for i, val in enumerate(["Likes","Replies","Retweets"]):
    plt.subplot(222+i)
    plt.title("Max "+val)
    heat = sns.heatmap(tweets_df.pivot_table(values=val,index="Cluster",columns="Category",aggfunc="max").fillna(0.0))
    heat.set_xticklabels(heat.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.show()

# %%
# Timeseries of Counts of Tweets by Cluster and Category

plt.figure(figsize=(18,16))
g = sns.FacetGrid(tweets_cat_clust_df, row = "Cluster", col="Category", margin_titles=True, sharey=False)
g.map(sns.lineplot, "Date", "Count", err_style=None)
for ax in g.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(45)
plt.show()

# %%
# PCA

from sklearn.decomposition import PCA
pca = PCA(n_components=3)
tweet_embedding_avg_matrix_pc = pca.fit_transform(tweet_embedding_avg_matrix)
tweets_df["PC1"] = tweet_embedding_avg_matrix_pc[:,0]
tweets_df["PC2"] = tweet_embedding_avg_matrix_pc[:,1]
tweets_df["PC3"] = tweet_embedding_avg_matrix_pc[:,2]

# %%
# PC Plots

# Organise colours
colours_unique_all, colours_scaled_all = scatter_cmap(list(tweets_df["Cluster"]))
tweets_df["colours_scaled"] = colours_scaled_all
tweets_df["period"] = tweets_df["Date"].apply(lambda x: (x >= dt.datetime.strptime("2018-12-02","%Y-%m-%d").date()) + (x > dt.datetime.strptime("2018-12-15","%Y-%m-%d").date()))

# All-time plot

plt.figure(figsize=(16,14))

scatter = plt.scatter(tweets_df["PC1"],
                      tweets_df["PC2"],
                      c=colours_scaled_all,
                      cmap = "viridis",
                      marker='.')
handles, labels = scatter.legend_elements()
plt.legend(handles, colours_unique_all)
plt.title("PC Plot for All Tweets by Cluster")
plt.xlabel("PC1")
plt.ylabel("PC2")

plt.show()

# Plots for each period

plt.figure(figsize=(16,6))

for i, p in enumerate(["Before","During","After"]):
    plt.subplot(131+i)
    tweets_df_filtered = tweets_df[tweets_df["period"] == i]
    colours_scaled = list(tweets_df_filtered["colours_scaled"])
    colours_unique = list(set(list(tweets_df_filtered["Cluster"])))
    scatter = plt.scatter(tweets_df_filtered["PC1"],
                tweets_df_filtered["PC2"],
                c=colours_scaled,
                cmap = "viridis",
                marker='.')
    handles, labels = scatter.legend_elements()
    plt.legend(handles, colours_unique)
    plt.title("PC Plot for Tweets "+p+" Conference by Cluster")
    plt.xlabel("PC1")
    plt.ylabel("PC2")

plt.show()

# Plots for each category

categories = list(tweets_df["Category"].unique())

plt.figure(figsize=(16,18))

for i, cat in enumerate(categories):
    plt.subplot(331+i)
    tweets_df_filtered = tweets_df[tweets_df["Category"] == cat]
    colours_scaled = list(tweets_df_filtered["colours_scaled"])
    colours_unique = list(set(list(tweets_df_filtered["Cluster"])))
    scatter = plt.scatter(tweets_df_filtered["PC1"],
                tweets_df_filtered["PC2"],
                c=colours_scaled,
                cmap = "viridis",
                marker='.')
    handles, labels = scatter.legend_elements()
    plt.legend(handles, colours_unique)
    plt.title("PC Plot for "+cat+" by Cluster")
    plt.xlabel("PC1")
    plt.ylabel("PC2")
