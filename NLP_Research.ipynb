# %% [markdown]
# <a href="https://colab.research.google.com/github/james-hughes1/wdss-nlp-project/blob/main/NLP_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing the Data

# %%
# Import libraries

import pandas as pd
import re
import datetime

# %%
# Add the .csv file to the workspace or this won't work

tweets_df = pd.read_csv('Twitter Scrape 2.csv', usecols=["ID", "Date", "Likes", "Replies", "Retweets", "User ID", "Username", "Followers", "Verified", "Content"],
                        nrows=900000, date_parser = pd.to_datetime, parse_dates=["Date"], encoding="UTF-8")

# %%
tweets_df
# Out:
#                          ID                      Date  Likes  Replies  \
# 0       1448438445546770432 2021-10-14 00:00:10+00:00      1        0
# 1       1448438526098481157 2021-10-14 00:00:29+00:00      1        0
# 2       1448438536332627971 2021-10-14 00:00:32+00:00      0        0
# 3       1448438610290782211 2021-10-14 00:00:50+00:00      4        0
# 4       1448438763022082050 2021-10-14 00:01:26+00:00      0        0
# ...                     ...                       ...    ...      ...
# 899995  1459930326499741700 2021-11-14 17:04:48+00:00      0        0
# 899996  1459930359727075333 2021-11-14 17:04:56+00:00      0        0
# 899997  1459930376407855106 2021-11-14 17:05:00+00:00      1        1
# 899998  1459930382468538369 2021-11-14 17:05:02+00:00      1        0
# 899999  1459930385601609728 2021-11-14 17:05:02+00:00      0        0
#
#         Retweets              User ID         Username  Followers  Verified  \
# 0              0            760449739         CBE_MIIS       1545         0
# 1              2  1288369706961973250  BetterFuturesAU        839         0
# 2              0            321986074   EINGazpromNews       1357         0
# 3              2             18781150      FreshEnergy      10064         0
# 4              0             55635996      Scotland4me       6308         0
# ...          ...                  ...              ...        ...       ...
# 899995         0           3048999762   Scilla_Seventy        335         0
# 899996         0  1159445850730455045  EcologyAfricaF1       1133         0
# 899997         0             50132801       padmorious       7813         0
# 899998         1             19870225  LindsayGrahamUK       8409         0
# 899999         0  1297070481225310208        biswastra        612         0
#
#                                                   Content
# 0       Bold #climate decisions from Congress  in thes...
# 1       In the lead-up to #COP26, the #BetterFuturesAU...
# 2       COP26 Warning: World's Listed Companies to Cau...
# 3       What role does Minnesota play at the UN Climat...
# 4       Media release: Rail and road freight industrie...
# ...                                                   ...
# 899995                                      #COP26 failed
# 899996  Greta Thunberg dismisses COP26 pact: 'The real...
# 899997  What bollocks will #JohnsonTheCorruptPM feed u...
# 899998        #COP26 in 2 minutes https://t.co/rBKpIS3h3T
# 899999  So much blah, blah, blah.....\nNow what? It's ...
#
# [900000 rows x 10 columns]

# %%
tweets_df.iloc[:5,-1]
# Out:
# 0    Bold #climate decisions from Congress  in thes...
# 1    In the lead-up to #COP26, the #BetterFuturesAU...
# 2    COP26 Warning: World's Listed Companies to Cau...
# 3    What role does Minnesota play at the UN Climat...
# 4    Media release: Rail and road freight industrie...
# Name: Content, dtype: object

# %%
# Use regex to clean tweets.

tweets_clean = []

for i in range(100000):
  tweet_raw = tweets_df.iloc[i,-1]
  tweet_edit_1 = re.sub('\n|http\S+', '', tweet_raw.lower().strip())
  tweet_edit_2 = re.sub('&amp;', 'and', tweet_edit_1)
  tweet_edit_3 = re.sub('\s*[.,:;-]\s*', ' ', tweet_edit_2)
  tweet_edit_4 = re.sub('[^a-z0-9 @#%$£]', '', tweet_edit_3)
  tweets_clean.append(tweet_edit_4)

# %%
tweets_clean[:5]
# Out:
# ['bold #climate decisions from congress in these coming weeks can impact the lives of americans and put the u s in a stronger position to support the goals of the #parisagreement #cop26 #climateaction #climatecrisis',
#  'in the lead up to #cop26 the #betterfuturesau local government sector working group is hosting a session on 18 october to discuss what cop26 means for local governments and how aus councils can get involved register for the event here #innovate4cities ',
#  'cop26 warning worlds listed companies to cause a temperature rise of 3anddeg c ',
#  'what role does minnesota play at the un climate change conference cop26 what is the u s bringing to the table at the global climate summit get answers to these questions and more next week at our behind the scenes pre cop26 webinar see you there ',
#  'media release rail and road freight industries pull together for cop26 trade event series of images available  contact alice@grm agencyan event raising awareness about the transition to net zero in the rail and road freight industries has just bee']

# %%
# Import libraries

import random
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %% [markdown]
# ## Frequency analysis

# %%
# Preprocessing hyperparameters.

vocab_size = 20000
max_length = 24

# Tokenize text data, converting to integers.

tokenizer = Tokenizer(oov_token="<OOV>",
                      num_words=vocab_size,
                      filters = '')
tokenizer.fit_on_texts(tweets_clean)

tweet_sequences = tokenizer.texts_to_sequences(tweets_clean)

# %%
dict(tokenizer.word_counts).items()
# Out:
# dict_items([('bold', 731), ('#climate', 3378), ('decisions', 291), ('from', 12809), ('congress', 124), ('in', 39443), ('these', 1940), ('coming', 1559), ('weeks', 1693), ('can', 7425), ('impact', 1085), ('the', 111095), ('lives', 435), ('of', 51878), ('americans', 40), ('and', 62310), ('put', 1052), ('u', 927), ('s', 573), ('a', 39815), ('stronger', 108), ('position', 272), ('to', 92990), ('support', 2127), ('goals', 849), ('#parisagreement', 389), ('#cop26', 45634), ('#climateaction', 4879), ('#climatecrisis', 3917), ('lead', 1401), ('up', 8498), ('#betterfuturesau', 2), ('local', 996), ('government', 2951), ('sector', 716), ('working', 1061), ('group', 574), ('is', 32817), ('hosting', 891), ('session', 397), ('on', 26723), ('18', 277), ('october', 1574), ('discuss', 1017), ('what', 8168), ('cop26', 33594), ('means', 551), ('for', 33646), ('governments', 1151), ('how', 7099), ('aus', 105), ('councils', 92), ('get', 3930), ('involved', 666), ('register', 1410), ('event', 2834), ('here', 3965), ('#innovate4cities', 5), ('warning', 226), ('worlds', 1011), ('listed', 45), ('companies', 1083), ('cause', 385), ('temperature', 296), ('rise', 455), ('3anddeg', 1), ('c', 402), ('role', 1190), ('does', 1416), ('minnesota', 2), ('play', 834), ('at', 19238), ('un', 2089), ('climate', 28745), ('change', 11507), ('conference', 4340), ('bringing', 303), ('table', 294), ('global', 5376), ('summit', 5709), ('answers', 99), ('questions', 627), ('more', 8822), ('next', 2530), ('week', 2774), ('our', 14937), ('behind', 412), ('scenes', 67), ('pre', 549), ('webinar', 481), ('see', 3189), ('you', 15244), ('there', 3660), ('media', 653), ('release', 197), ('rail', 448), ('road', 882), ('freight', 50), ('industries', 189), ('pull', 115), ('together', 1508), ('trade', 595), ('series', 801), ('images', 80), ('available', 412), ('contact', 83), ('alice@grm', 1), ('agencyan', 1), ('raising', 176), ('awareness', 319), ('about', 8705), ('transition', 1120), ('net', 2806), ('zero', 3402), ('has', 6198), ('just', 5542), ('bee', 10), ('@zacgoldsmith', 49), ('@cop26', 18840), ('plan', 1974), ('protect', 902), ('30%', 76), ('planet', 2603), ('proposed', 87), ('by', 10733), ('conservation', 131), ('industry', 959), ('which', 2306), ('partners', 391), ('with', 16080), ('most', 1853), ('polluting', 207), ('corporations', 117), ('will', 17325), ('dispossess', 1), ('millions', 282), ('africa', 485), ('asia', 120), ('its', 8117), ('#biggreenlie', 1), ('find', 1814), ('out', 6522), ('as', 12080), ('world', 8156), ('gears', 44), ('ive', 499), ('list', 405), ('some', 2507), ('my', 2641), ('blogs', 26), ('popular', 53), ('articles', 87), ('absolute', 208), ('vital', 424), ('nature', 1024), ('urgent', 775), ('action', 5991), ('pandemic', 330), ('end', 1125), ('wont', 1182), ('unless', 262), ('we', 17294), ('do', 5404), ('something', 738), ('@oliviaotigbah', 1), ('are', 16196), ('reason', 322), ('why', 3856), ('olivia', 15), ('held', 539), ('glasgow', 9665), ('show', 1586), ('driver', 55), ('natural', 446), ('resources', 538), ('maximum', 41), ('nuclear', 479), ('sub', 32), ('station', 107), ('around', 2019), ('corner', 395), ('better', 1188), ('have', 9788), ('treadmill', 1), ('home', 929), ('15', 392), ('yrs', 68), ('time', 4488), ('be', 18654), ('no', 4729), ('park', 182), ('or', 4337), ('free', 1284), ('public', 1246), ('space', 519), ('outdoor', 18), ('activities', 270), ('rbas', 2), ('guy', 90), ('debelle', 3), ('also', 1789), ('said', 1125), ('simply', 188), ('shutting', 27), ('down', 1473), ('parts', 90), ('economy', 687), ('pursuit', 18), ('emissions', 3774), ('targets', 1140), ('unlikely', 211), ('deliver', 788), ('socially', 22), ('optimal', 10), ('@australian', 25), ('news', 2242), ('investors', 181), ('could', 2299), ('shun', 6), ('australia', 1474), ('without', 853), ('2050', 892), ('commitment', 650), ('rba', 4), ('warns', 334), ('#emissions', 249), ('#netzero', 2241), ('#zeroemissions', 34), ('@adbhq', 12), ('plays', 88), ('supporting', 430), ('developing' ...

# %%
list(zip(dict(tokenizer.word_counts)))
# Out:
# [('bold',),
#  ('#climate',),
#  ('decisions',),
#  ('from',),
#  ('congress',),
#  ('in',),
#  ('these',),
#  ('coming',),
#  ('weeks',),
#  ('can',),
#  ('impact',),
#  ('the',),
#  ('lives',),
#  ('of',),
#  ('americans',),
#  ('and',),
#  ('put',),
#  ('u',),
#  ('s',),
#  ('a',),
#  ('stronger',),
#  ('position',),
#  ('to',),
#  ('support',),
#  ('goals',),
#  ('#parisagreement',),
#  ('#cop26',),
#  ('#climateaction',),
#  ('#climatecrisis',),
#  ('lead',),
#  ('up',),
#  ('#betterfuturesau',),
#  ('local',),
#  ('government',),
#  ('sector',),
#  ('working',),
#  ('group',),
#  ('is',),
#  ('hosting',),
#  ('session',),
#  ('on',),
#  ('18',),
#  ('october',),
#  ('discuss',),
#  ('what',),
#  ('cop26',),
#  ('means',),
#  ('for',),
#  ('governments',),
#  ('how',),
#  ('aus',),
#  ('councils',),
#  ('get',),
#  ('involved',),
#  ('register',),
#  ('event',),
#  ('here',),
#  ('#innovate4cities',),
#  ('warning',),
#  ('worlds',),
#  ('listed',),
#  ('companies',),
#  ('cause',),
#  ('temperature',),
#  ('rise',),
#  ('3anddeg',),
#  ('c',),
#  ('role',),
#  ('does',),
#  ('minnesota',),
#  ('play',),
#  ('at',),
#  ('un',),
#  ('climate',),
#  ('change',),
#  ('conference',),
#  ('bringing',),
#  ('table',),
#  ('global',),
#  ('summit',),
#  ('answers',),
#  ('questions',),
#  ('more',),
#  ('next',),
#  ('week',),
#  ('our',),
#  ('behind',),
#  ('scenes',),
#  ('pre',),
#  ('webinar',),
#  ('see',),
#  ('you',),
#  ('there',),
#  ('media',),
#  ('release',),
#  ('rail',),
#  ('road',),
#  ('freight',),
#  ('industries',),
#  ('pull',),
#  ('together',),
#  ('trade',),
#  ('series',),
#  ('images',),
#  ('available',),
#  ('contact',),
#  ('alice@grm',),
#  ('agencyan',),
#  ('raising',),
#  ('awareness',),
#  ('about',),
#  ('transition',),
#  ('net',),
#  ('zero',),
#  ('has',),
#  ('just',),
#  ('bee',),
#  ('@zacgoldsmith',),
#  ('@cop26',),
#  ('plan',),
#  ('protect',),
#  ('30%',),
#  ('planet',),
#  ('proposed',),
#  ('by',),
#  ('conservation',),
#  ('industry',),
#  ('which',),
#  ('partners',),
#  ('with',),
#  ('most',),
#  ('polluting',),
#  ('corporations',),
#  ('will',),
#  ('dispossess',),
#  ('millions',),
#  ('africa',),
#  ('asia',),
#  ('its',),
#  ('#biggreenlie',),
#  ('find',),
#  ('out',),
#  ('as',),
#  ('world',),
#  ('gears',),
#  ('ive',),
#  ('list',),
#  ('some',),
#  ('my',),
#  ('blogs',),
#  ('popular',),
#  ('articles',),
#  ('absolute',),
#  ('vital',),
#  ('nature',),
#  ('urgent',),
#  ('action',),
#  ('pandemic',),
#  ('end',),
#  ('wont',),
#  ('unless',),
#  ('we',),
#  ('do',),
#  ('something',),
#  ('@oliviaotigbah',),
#  ('are',),
#  ('reason',),
#  ('why',),
#  ('olivia',),
#  ('held',),
#  ('glasgow',),
#  ('show',),
#  ('driver',),
#  ('natural',),
#  ('resources',),
#  ('maximum',),
#  ('nuclear',),
#  ('sub',),
#  ('station',),
#  ('around',),
#  ('corner',),
#  ('better',),
#  ('have',),
#  ('treadmill',),
#  ('home',),
#  ('15',),
#  ('yrs',),
#  ('time',),
#  ('be',),
#  ('no',),
#  ('park',),
#  ('or',),
#  ('free',),
#  ('public',),
#  ('space',),
#  ('outdoor',),
#  ('activities',),
#  ('rbas',),
#  ('guy',),
#  ('debelle',),
#  ('also',),
#  ('said',),
#  ('simply',),
#  ('shutting',),
#  ('down',),
#  ('parts',),
#  ('economy',),
#  ('pursuit',),
#  ('emissions',),
#  ('targets',),
#  ('unlikely',),
#  ('deliver',),
#  ('socially',),
#  ('optimal',),
#  ('@australian',),
#  ('news',),
#  ('investors',),
#  ('could',),
#  ('shun',),
#  ('australia',),
#  ('without',),
#  ('2050',),
#  ('commitment',),
#  ('rba',),
#  ('warns',),
#  ('#emissions',),
#  ('#netzero',),
#  ('#zeroemissions',),
#  ('@adbhq',),
#  ('plays',),
#  ('supporting',),
#  ('developing',),
#  ('countries',),
#  ('across',),
#  ('#asia',),
#  ('delighted',),
#  ('bank',),
#  ('announce',),
#  ('they',),
#  ('increasing',),
#  ('their',),
#  ('finance',),
#  ('ambition',),
#  ('ahead',),
#  ('critical',),
#  ('region',),
#  ('adapt',),
#  ('impacts',),
#  ('#climatechange',),
#  ('tell',),
#  ('president',),
#  ('biden',),
#  ('act',),
#  ('policy',),
#  ('before',),
#  ('united',),
#  ('nations',),
#  ('oct',),
#  ('31st',),
#  ('@potus',),
#  ('@vp',),
#  ('@sierraclub',),
#  ('#climateemergency',),
#  ('@cherylkernot',),
#  ('good',),
#  ('if',),
#  ('he',),
#  ('significant',),
#  ('but',),
#  ('i',),
#  ('suspect',),
#  ('that',),
#  ('this',),
#  ('enough',),
#  ('cover',),
#  ('greenwashing',),
#  ('needed',),
#  ('#scottyfromgasmarketing',),
#  ('through',),
#  ('election',),
#  ('campaign',),
#  ('#auspol',),
#  ('cynical',),
#  ('morrison',),
#  ('agreeing',),
#  ('nationals',),
#  ('demand',),
#  ('spend',),
#  ('taxpayer',),
#  ('$$to',),
#  ('increase',),
#  ('carbon',),
#  ('emissionsas',),
#  ('price',),
#  ('agreement',),
#  ('reduce',),
#  ('0',),
#  ('donate',),
#  ('@climate200',),
#  ('oust',),
#  ('key',),
#  ('lib',),
#  ('mps#auspol',),
#  ('#morrisonfailure',),
#  ('encouraging',),
#  ('@sddecleve',),
#  ('@commongfest',),
#  ('@weallalliance',),
#  ('@weallscotland',),
#  ('@ktrebeck',),
#  ('@curiousjanex',),
#  ('@clubofrome',),
#  ('make',),
#  ('mistake',),
#  ('australias',),
#  ('2030',),
#  ('reduction',),
#  ('target',),
#  ('minimum',),
#  ('must',),
#  ('take',),
#  ('37',),
#  ('42%',),
#  ('preferred',),
#  ('federal',),
#  ('not',),
#  ('same',),
#  ('thing',),
#  ('#paris',),
#  ('requires',),
#  ('former',),
#  ('@pamela49986311',),
#  ('@p49986311',),
#  ('@unfccc',),
#  ('@cop26coalition',),
#  ('welcome',),
#  ('warrior',),
#  ('@drchriscandido',),
#  ('@rebeccabentley',),
#  ('@saminmarzban',),
#  ('joined',),
#  ('forces',),
#  ('write',),
#  ('piece',),
#  ('@buildingscities',),
#  ('reconcile',),
#  ('healthy',),
#  ('indoor',),
#  ('environments',),
#  ('mitigation',),
#  ('#healthyenvironments',),
#  ('@msdsocial',),
#  ('@unimelb',),
#  ('looking',),
#  ('soft',),
#  ('solution',),
#  ('ambitious',),
#  ('doesnt',),
#  ('even',),
#  ('qualify',),
#  ('fig',),
#  ('leaf',),
#  ('should',),
#  ('stay',),
#  ('own',),
#  ('his',),
#  ('failure',),
#  ('it',),
#  ('looks',),
#  ('like',),
#  ('#lnp',),
#  ('#australian',),
#  ('libs',),
#  ('being',),
#  ('dragged',),
#  ('petulant',),
#  ('child',),
#  ('#cop26glasgow',),
#  ('remains',),
#  ('seen',),
#  ('whether',),
#  ('meaningful',),
#  ('positive',),
#  ('contribution',),
#  ('negative',),
#  ('current',),
#  ('future',),
#  ('generations',),
#  ('bottom',),
#  ('line',),
#  ('than',),
#  ('important',),
#  ('ok',),
#  ('so',),
#  ('shouldve',),
#  ('numbered',),
#  ('tweets',),
#  ('never',),
#  ('worked',),
#  ('threads',),
#  ('right',),
#  ('drift',),
#  ('@bourryyang',),
#  ('@climatehuman',),
#  ('month',),
#  ('lets',),
#  ('remember',),
#  ('international',),
#  ('agreements',),
#  ('alone',),
#  ('reverse',),
#  ('upward',),
#  ('trajectory',),
#  ('need',),
#  ('regional',),
#  ('levels',),
#  ('#greenjobs',),
#  ('one',),
#  ('go',),
#  ('join',),
#  ('us',),
#  ('thursday',),
#  ('21',),
#  ('kick',),
#  ('off',),
#  ('digital',),
#  ('featuring',),
#  ('30',),
#  ('speakers',),
#  ('eight',),
#  ('unmissable',),
#  ('sessions',),
#  ('tickets',),
#  ('students',),
#  ('civil',),
#  ('society',),
#  ('now',),
#  ('institutions',),
#  ('seeking',),
#  ('esg',),
#  ('driven',),
#  ('projects',),
#  ('@citiaustralia',),
#  ('ceo',),
#  ('marc',),
#  ('luet',),
#  ('tells',),
#  ('@cnbci',),
#  ('huge',),
#  ('trillions',),
#  ('dollars',),
#  ('deployed',),
#  ('#greenwashing',),
#  ('needs',),
#  ('avoided',),
#  ('#ausbiz',),
#  ('#citiinvest2021',),
#  ('@asiasquawkbox',),
#  ('china',),
#  ('goes',),
#  ('back',),
#  ('coal',),
#  ('combat',),
#  ('power',),
#  ('crisis',),
#  ('still',),
#  ('were',),
#  ('fiddling',),
#  ('#ecologicalemergency',),
#  ('#climatesolutions',),
#  ('however',),
#  ('any',),
#  ('signed',),
#  ('notarized',),
#  ('penalty',),
#  ('non',),
#  ('compliance',),
#  ('all',),
#  ('coordinated',),
#  ('community',),
#  ('#auspol2021',),
#  ('drop',),
#  ('40%',),
#  ('pledges',),
#  ('#climateactionnow',),
#  ('chevrons',),
#  ('use',),
#  ('wind',),
#  ('solar',),
#  ('drill',),
#  ('oil#cop26',),
#  ('#solarenergy#climatechange',),
#  ('#whatsapp',),
#  ('#climatestrike',),
#  ('#climatejustice',),
#  ('#climatepledge',),
#  ('@brianlilley',),
#  ('youre',),
#  ('going',),
#  ('where',),
#  ('delegates',),
#  ('barred',),
#  ('fully',),
#  ('vaccinated',),
#  ('jokes',),
#  ('pakistan',),
#  ('facing',),
#  ('an',),
#  ('existential',),
#  ('crisis#cop26',),
#  ('#glaciers',),
#  ('#globalwarming#climatechange',),
#  ('#pakistan',),
#  ('beggars',),
#  ('belief',),
#  ('yet',),
#  ('achieve',),
#  ('includes',),
#  ('exporting',),
#  ('nb',),
#  ('new',),
#  ('fired',),
#  ('electricity',),
#  ('plant',),
#  ('money',),
#  ('dunny',),
#  ('bc',),
#  ('renewables',),
#  ('already',),
#  ('cheaper',),
#  ('whatever',),
#  ('massacre',),
#  ('victims',),
#  ('family',),
#  ('call',),
#  ('arrest',),
#  ('irans',),
#  ('ebrahim',),
#  ('raisi',),
#  ('talk',),
#  ('scotsman',),
#  ('100',),
#  ('responsible',),
#  ('70%',),
#  ('do#cop26',),
#  ('single',),
#  ('biggest',),
#  ('health',),
#  ('threat',),
#  ('humanity',),
#  ('special',),
#  ('report',),
#  ('argument',),
#  ('who',),
#  ('2021',),
#  ('covid',),
#  ('19',),
#  ('follow',),
#  ('murdoch',),
#  ('greenwash',),
#  ('liberal',),
#  ('party',),
#  ('very',),
#  ('freedom',),
#  ('day',),
#  ('nsw',),
#  ('politics',),
#  ('latest',),
#  ('podcast',),
#  ('listen',),
#  ('engage',),
#  ('subscribe',),
#  ('#nswpol',),
#  ('via',),
#  ('@newpoliticsau',),
#  ('#1988massacre',),
#  ('#irans',),
#  ('australian',),
#  ('coalition',),
#  ('nats',),
#  ('scott',),
#  ('cant',),
#  ('hide',),
#  ('matey',),
#  ('dont',),
#  ('buy',),
#  ('lies',),
#  ('joyce',),
#  ('confirms',),
#  ('rort',),
#  ('include',),
#  ('$3',),
#  ('billion',),
#  ('subsidy',),
#  ('@crikeynews',),
#  ('asias',),
#  ('#energy',),
#  ('pivot',),
#  ('clinging',),
#  ('#coal',),
#  ('bad',),
#  ('d',),
#  ('economy#cop26',),
#  ('dr',),
#  ('was',),
#  ('first',),
#  ('order',),
#  ('riskto',),
#  ('system',),
#  ('w',),
#  ('broad',),
#  ('ranging',),
#  ('including',),
#  ('households',),
#  ('businesses@rbainfo',),
#  ('drive',),
#  ('couldnt',),
#  ('timely',),
#  ('fire',),
#  ('lit',),
#  ('under',),
#  ('gov',),
#  ('eve',),
#  ('timeframe',),
#  ('pm',),
#  ('embarrassed',),
#  ('into',),
#  ('attending',),
#  ('congrats',),
#  ('producers',),
#  ('cinematographer',),
#  ('greg',),
#  ('harrington',),
#  ('study',),
#  ('says',),
#  ('panels',),
#  ('half',),
#  ('roofs',),
#  ('meet',),
#  ('needs#cop26',),
#  ('taking',),
#  ('dictation',),
#  ('discarding',),
#  ('sense',),
#  ('disbelief',),
#  ('chinas',),
#  ('build',),
#  ('plants',),
#  ('derail',),
#  ('swedish',),
#  ('activist',),
#  ('@gretathunberg',),
#  ('high',),
#  ('expectations',),
#  ('far',),
#  ('would',),
#  ('she',),
#  ('told',),
#  ('@reuters',),
#  ('interview',),
#  ('known',),
#  ('26th',),
#  ('scheduled',),
#  ('city',),
#  ('scotland',),
#  ('between',),
#  ('31',),
#  ('12',),
#  ('november',),
#  ('presidency',),
#  ('kingdom',),
#  ('meant',),
#  ('another',),
#  ('overseas',),
#  ('trip',),
#  ('quarantine',),
#  ('despite',),
#  ('science',),
#  ('leaders',),
#  ('advocating',),
#  ('actionbut',),
#  ('then',),
#  ('king',),
#  ('england',),
#  ('male',),
#  ('head',),
#  ('state',),
#  ('spoke',),
#  ('@ausrepublic',),
#  ('@peterfitz',),
#  ('@dmelissa2',),
#  ('always',),
#  ('look',),
#  ('crap',),
#  ('think',),
#  ('landfill',),
#  ('@woolworths',),
#  ('@aldiaustralia',),
#  ('@costcoaus',),
#  ('@coles',),
#  ('serious',),
#  ('stop',),
#  ('selling',),
#  ('1',),
#  ('plastic',),
#  ('@matflamm',),
#  ('hi',),
#  ('unroll',),
#  ('asked',),
#  ('#weo2021',),
#  ('crucial',),
#  ('shows',),
#  ('while',),
#  ('enjoy',),
#  ('@reicurran',),
#  ('@natnewswatch',),
#  ('certainly',),
#  ('thorny',),
#  ('forum',),
#  ('waived',),
#  ('restrictions',),
#  ('ensure',),
#  ('people',),
#  ('contribute',),
#  ('essential',),
#  ('deliberations',),
#  ('harder',),
#  ('decide',),
#  ('minor',),
#  ('forums',),
#  ('house',),
#  ('commons',),
#  ('called',),
#  ('soon',),
#  ('continues',),
#  ('display',),
#  ('embarrassing',),
#  ('lack',),
#  ('tackling',),
#  ('@peterkhalilmp',),
#  ('share',),
#  ('labors',),
#  ('alternative',),
#  ('vision',),
#  ('upcoming',),
#  ('@newstalkzb',),
#  ('@jamespeshaw',),
#  ('comment',),
#  ('anything',),
#  ('other',),
#  ('evs',),
#  ('lockdown',),
#  ('publicity',),
#  ('nod',),
#  ('brownie',),
#  ('points',),
#  ('@jengleruk',),
#  ('best',),
#  ('cancel',),
#  ('superspreader',),
#  ('imagine',),
#  ('variant',),
#  ('soup',),
#  ('produce',),
#  ('seeing',),
#  ('enormity',),
#  ('smallness',),
#  ('enemy',),
#  ('destroying',),
#  ('ayn',),
#  ('rand',),
#  ('atlas',),
#  ('shrugged#climate',),
#  ('#persist',),
#  ('#climatecommunity',),
#  ('#writingcommunity',),
#  ('#climatejournalism',),
#  ('@bernardkeane',),
#  ('total',),
#  ('waste',),
#  ('continue',),
#  ('exports',),
#  ('scientist',),
#  ('#syukuromanabe',),
#  ('inspiring',),
#  ('many',),
#  ('great',),
#  ('choice',),
#  ('@nobelprize',),
#  ('especially',),
#  ('climatecrisis',),
#  ('nov',),
#  ('@hearyanow',),
#  ('congratulations',),
#  ('well',),
#  ('deserved',),
#  ('arrested',),
#  ('comes',),
#  ('struan',),
#  ('stevenson',),
#  ('@denniallen',),
#  ('bit',),
#  ('clean',),
#  ('environment',),
#  ('air',),
#  ('water',),
#  ('land',),
#  ('semantics',),
#  ('inaction',),
#  ('obfuscation',),
#  ('flood',),
#  ('want',),
#  ('hear',),
#  ('@psychicpenny',),
#  ('@hipenergy',),
#  ('@pritipatel',),
#  ('@policescotland',),
#  ('hahahahahaha',),
#  ('2',),
#  ('houses',),
#  ('start',),
#  ('invasion',),
#  ('@tommyfree98',),
#  ('@silverparrottim',),
#  ('give',),
#  ('your',),
#  ('bedrooms',),
#  ('british',),
#  ('homeless',),
#  ('@fordfoundation',),
#  ('worst',),
#  ('ever',),
#  ('happened',),
#  ('christopher',),
#  ('columbus',),
#  ('slaughtering',),
#  ('destruction',),
#  ('mother',),
#  ('earth',),
#  ('@@sbsnews',),
#  ('natura',),
#  ('maters',),
#  ('sos',),
#  ('3',),
#  ('communicate',),
#  ('ways',),
#  ('wisop',),
#  ('original',),
#  ('tongue',),
#  ('been',),
#  ('sending',),
#  ('strong',),
#  ('signals',),
#  ('#naturedeal',),
#  ('#precop26',),
#  ('#sdgs',),
#  ('#unitednations',),
#  ('#christmas',),
#  ('nowdo',),
#  ('sign',),
#  ('havent',),
#  ('already#climatecrisis',),
#  ('lamb',),
#  ('beast',),
#  ('come',),
#  ('1st',),
#  ('cop26america',),
#  ('gives',),
#  ('catholicism',),
#  ('wonders',),
#  ('after',),
#  ('worship',),
#  ('him',),
#  ('saying',),
#  ('unto',),
#  ('live',),
#  ('alok',),
#  ('sharma',),
#  ('@cop26stop',),
#  ('endorsing',),
#  ('deployment',),
#  ('#hydropower',),
#  ('guardian',),
#  ('#solar',),
#  ('powered',),
#  ('skyscraper',),
#  ('sources',),
#  ('supply',),
#  ('cities',),
#  ('#futuristic',),
#  ('#buildingfutures',),
#  ('@rishisunak',),
#  ('uk',),
#  ('commit',),
#  ('additional',),
#  ('funding',),
#  ('contributions',),
#  ('50%',),
#  ('fair',),
#  ('true',),
#  ('turning',),
#  ('point',),
#  ('bare',),
#  ('launch',),
#  ('decisive',),
#  ('decade',),
#  ('momentum',),
#  ('keep',),
#  ('5c',),
#  ('within',),
#  ('reach',),
#  ('wave',),
#  ('expert',),
#  ('fears',),
#  ('fucking',),
#  ('rocket',),
#  ('much',),
#  ('bastards',),
#  ('earn',),
#  ('approaches',),
#  ('stand',),
#  ('common',),
#  ('living',),
#  ('against',),
#  ('fathomless',),
#  ('greed',),
#  ('fossil',),
#  ('fuel',),
#  ('corrupt',),
#  ('enablers',),
#  ('#peoplevsfossilfuels',),
#  ('virtual',),
#  ('built',),
#  ('pavilion',),
#  ('online',),
#  ('dedicating',),
#  ('entire',),
#  ('regions',),
#  ('11',),
#  ('@iclei',),
#  ('#thinkglobalactlocal',),
#  ('#buildings',),
#  ('#nzeb',),
#  ('#greenbuilding',),
#  ('#netzone',),
#  ('@aloksharmardg',),
#  ('happily',),
#  ('skipping',),
#  ('circus',),
#  ('davos',),
#  ('crowd',),
#  ('takes',),
#  ('over',),
#  ('grouping',),
#  ('business',),
#  ('top',),
#  ('exes',),
#  ('amazon',),
#  ('mcdonalds',),
#  ('mars',),
#  ('starbucks',),
#  ('linkedin',),
#  ('microsoft',),
#  ('airlines',),
#  ('bazaar',),
#  ('negotiation',),
#  ('@borisjohnson',),
#  ('@scotgovnetzero',),
#  ('@nicolasturgeon',),
#  ('@lornaslater',),
#  ('@danjoergensen',),
#  ('catering',),
#  ('100%',),
#  ('based',),
#  ('real',),
#  ('leadership',),
#  ('major',),
#  ('source',),
#  ('greenhouse',),
#  ('gases',),
#  ('animal',),
#  ('agriculture',),
#  ('rebounding',),
#  ('did',),
#  ('trump',),
#  ('please',),
#  ('explain',),
#  ('markets',),
#  ('rule',),
#  ('apparently',),
#  ('word',),
#  ('@climateenvoy',),
#  ('militarisms',),
#  ('effect',),
#  ('link',),
#  ('starts',),
#  ('less',),
#  ('3weeks',),
#  ('read',),
#  ('@rechargenews',),
#  ...]

# %%
freq_analysis_df = pd.DataFrame(data = dict(tokenizer.word_counts).items(),
                                columns = ["Word", "Count"]).sort_values(by="Count",ascending=False)

# %%
freq_analysis_df.head(50)
# Out:
#         Word   Count
# 11       the  111095
# 22        to   92990
# 15       and   62310
# 13        of   51878
# 26    #cop26   45634
# 19         a   39815
# 5         in   39443
# 47       for   33646
# 45     cop26   33594
# 37        is   32817
# 73   climate   28745
# 40        on   26723
# 71        at   19238
# 118   @cop26   18840
# 188       be   18654
# 133     will   17325
# 161       we   17294
# 165      are   16196
# 129     with   16080
# 272     this   15770
# 91       you   15244
# 85       our   14937
# 271     that   14040
# 367       it   13356
# 3       from   12809
# 142       as   12080
# 74    change   11507
# 124       by   10733
# 325      not   10070
# 182     have    9788
# 170  glasgow    9665
# 82      more    8822
# 110    about    8705
# 30        up    8498
# 477      all    8406
# 44      what    8168
# 143    world    8156
# 138      its    8117
# 269        i    8004
# 9        can    7425
# 49       how    7099
# 238     they    6555
# 141      out    6522
# 825     your    6350
# 114      has    6198
# 420       us    6099
# 268      but    6036
# 156   action    5991
# 243    ahead    5883
# 507       an    5857
